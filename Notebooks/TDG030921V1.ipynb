# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
invtrans = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/TDG/INVTRANS.csv")

# %%
invtrans.head()
# Out:
#      ITDATE      SKU  ITQTY ITSTUN    IG  ... PLANNING ABC  UOM  CREATION   CAT
# 0  20000929  SKU8590    6.0     BX   IG2  ...        1   C   BX  20000929  CAT1
# 1  20000929  SKU8594    1.0     BX   IG2  ...        1   C   BX  20000929  CAT1
# 2  20000929  SKU8598   74.0     BX   IG2  ...        1   C   BX  20000929  CAT1
# 3  20000929  SKU9024   17.0     BX  IG12  ...        1   C   BG  20000929  CAT2
# 4  20000929  SKU9036   13.0     BD  IG12  ...        0   A  BDL  20000929  CAT2
#
# [5 rows x 13 columns]

# %%
invtrans.tail()
# Out:
#          ITDATE      SKU  ITQTY ITSTUN    IG  ... PLANNING ABC  UOM  CREATION    CAT
# 20745  20201213  SKU9935   22.0     BG  IG13  ...        1   C   BG  20090810   CAT3
# 20746  20201213  SKU9936    2.0     BG  IG13  ...        0   C   BG  20090810   CAT3
# 20747  20201213  SKU9973    1.0     BX  IG13  ...        1   C   BX  20100408   CAT3
# 20748  20201213  SKU9987    1.0     BX  IG13  ...        0   C   BX  20060222   CAT3
# 20749  20210122  SKU1173   19.0     RL  IG16  ...        1   B   RL  20140910  CAT12
#
# [5 rows x 13 columns]

# %%
items = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/TDG/ITEMS.csv")

# %%
items.head()
# Out:
#     SKU    IG     IPG     HTS  CLASS  PLANNING ABC UOM  CREATION    CAT
# 0  SKU1  IG71     NaN  HTS143      1         1   A  PC  20160914  CAT14
# 1  SKU2  IG71     NaN  HTS143      1         1   B  PC  20160914  CAT14
# 2  SKU3  IG71     NaN  HTS143      1         1   B  EA  20160630  CAT14
# 3  SKU4  IG71     NaN  HTS143      1         1   B  EA  20160630  CAT14
# 4  SKU5  IG22  IPG542   HTS48      1         1   C  RL  20180919   CAT7

# %%
items.tail()
# Out:
#             SKU    IG     IPG     HTS  CLASS  PLANNING ABC UOM  CREATION    CAT
# 11516  SKU11517  IG58     NaN  HTS133      2         0   C  PC  20110624  CAT16
# 11517  SKU11518  IG58     NaN  HTS133      2         0   C  PC  20110624  CAT16
# 11518  SKU11519  IG58     NaN  HTS110      1         1   C  PC  20110624  CAT16
# 11519  SKU11520  IG43  IPG763   HTS99      1         0   C  BX  20180521  CAT10
# 11520  SKU11521  IG43  IPG872   HTS89      2         0   C  BX  20161116  CAT10

# %%
loctrans = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/TDG/LOCTRANS.csv")

# %%
loctrans.head()
# Out:
#       TDATE      SKU   LOC  QTY  AISLE  ... PLANNING  ABC UOM  CREATION    CAT
# 0  20180210  SKU3921  17Q3 -1.0   17.0  ...        1    B  PC  20161028  CAT17
# 1  20180210  SKU3922  17Q2  1.0   17.0  ...        1    B  PC  20161028  CAT17
# 2  20180210  SKU3923  17W2  4.0   17.0  ...        1    C  PC  20161028  CAT17
# 3  20180210  SKU3924  17B2 -1.0   17.0  ...        1    B  PC  20161028  CAT17
# 4  20180210  SKU3926  15P7 -2.0   15.0  ...        1    C  PC  20161028  CAT17
#
# [5 rows x 17 columns]

# %%
loctrans.tail()
# Out:
#           TDATE       SKU   LOC   QTY  AISLE  ... PLANNING  ABC UOM  CREATION   CAT
# 17002  20210208   SKU9263  38B5   1.0   38.0  ...        1    C  RL  20080117  CAT7
# 17003  20210209  SKU11471  38C2  -4.0   38.0  ...        0    C  BG  20100527  CAT7
# 17004  20210209   SKU2587  38D2 -17.0   38.0  ...        0    C  BX  20171115  CAT7
# 17005  20210209   SKU9182  38D1   1.0   38.0  ...        1    A  RL  20010314  CAT7
# 17006  20210209   SKU9518  38C6  -3.0   38.0  ...        0    C  BX  20020823  CAT7
#
# [5 rows x 17 columns]

# %%
locations = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/TDG/LOCATIONS.csv")

# %%
locations.head()
# Out:
#    WHS ZONE TYPE  AISLE COLUMN  SHELF      LOC
# 0   80   WH  NaN    NaN    NaN      0  ACTELMA
# 1   80   WH  NaN    NaN    NaN      0  CY BULK
# 2   80   WH  NaN    NaN    NaN      0    DAVE1
# 3   80   WH  NaN    NaN    NaN      0   DEBBIE
# 4   80   WH  NaN    NaN    NaN      0     DM01

# %%
loctrans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TDATE     17007 non-null  int64
#  1   SKU       17007 non-null  object
#  2   LOC       17007 non-null  object
#  3   QTY       17007 non-null  float64
#  4   AISLE     16935 non-null  float64
#  5   COLUMN    16935 non-null  object
#  6   SHELF     17007 non-null  int64
#  7   TYPE      16935 non-null  object
#  8   IG        17007 non-null  object
#  9   IPG       8381 non-null   object
#  10  HTS       16997 non-null  object
#  11  CLASS     17007 non-null  int64
#  12  PLANNING  17007 non-null  int64
#  13  ABC       17007 non-null  object
#  14  UOM       17007 non-null  object
#  15  CREATION  17007 non-null  int64
#  16  CAT       17007 non-null  object
# dtypes: float64(2), int64(5), object(10)
# memory usage: 2.2+ MB

# %%
loctrans.describe()
# Out:
#               TDATE           QTY  ...      PLANNING      CREATION
# count  1.700700e+04  17007.000000  ...  17007.000000  1.700700e+04
# mean   2.019243e+07    -21.361278  ...      0.834068  2.012587e+07
# std    8.798399e+03   1245.889605  ...      0.392040  3.752662e+04
# min    2.018021e+07 -80500.000000  ...      0.000000  2.000093e+07
# 25%    2.018103e+07     -5.000000  ...      1.000000  2.011062e+07
# 50%    2.019092e+07     -1.000000  ...      1.000000  2.012012e+07
# 75%    2.020121e+07      4.000000  ...      1.000000  2.016032e+07
# max    2.021021e+07  74000.000000  ...      9.000000  2.020102e+07
#
# [8 rows x 7 columns]

# %%
loctransCX = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/TDG/LOCTRANSCX.csv")

# %%
loctransCX.head()
# Out:
#       TDATE      SKU   LOC  QTY  AISLE  ... ABC  UOM  CREATION    CAT      COSTX
# 0  20180210  SKU3921  17Q3 -1.0   17.0  ...   B   PC  20161028  CAT17  -289.8802
# 1  20180210  SKU3922  17Q2  1.0   17.0  ...   B   PC  20161028  CAT17   289.5527
# 2  20180210  SKU3923  17W2  4.0   17.0  ...   C   PC  20161028  CAT17  1111.3121
# 3  20180210  SKU3924  17B2 -1.0   17.0  ...   B   PC  20161028  CAT17  -266.8633
# 4  20180210  SKU3926  15P7 -2.0   15.0  ...   C   PC  20161028  CAT17  -517.0436
#
# [5 rows x 18 columns]

# %%
loctransCX.tail()
# Out:
#           TDATE      SKU    LOC   QTY  AISLE  ... ABC  UOM  CREATION   CAT      COSTX
# 17002  20201213  SKU8964  23C10   1.0   23.0  ...   C   BX  20000930  CAT2   316.3834
# 17003  20201213  SKU8971   21I2   2.0   21.0  ...   C   BX  20001001  CAT2   626.9100
# 17004  20201213  SKU8972   22F8  15.0   22.0  ...   C   BX  20000930  CAT2  4959.6974
# 17005  20201213  SKU8972   24I4  -4.0   24.0  ...   C   BX  20000930  CAT2 -1322.5860
# 17006  20201213  SKU8979   20G1  -1.0   20.0  ...   C   BX  20050603  CAT2  -255.2001
#
# [5 rows x 18 columns]

# %%
loctrans['ABC'].value_counts(normalize=True)
# Out:
# A    0.447874
# C    0.343212
# B    0.208914
# Name: ABC, dtype: float64

# %%
loctrans['CAT'].value_counts(normalize=True)
# Out:
# CAT17    0.241430
# CAT12    0.155230
# CAT14    0.148939
# CAT16    0.147233
# CAT8     0.134004
# CAT7     0.072558
# CAT3     0.031752
# CAT10    0.015347
# CAT5     0.011819
# CAT2     0.011760
# CAT9     0.009408
# CAT1     0.008820
# CAT4     0.006115
# CAT15    0.005116
# CAT6     0.000412
# CAT11    0.000059
# Name: CAT, dtype: float64

# %%
loctrans['CLASS'].value_counts(normalize=True)
# Out:
# 1    0.927148
# 2    0.072852
# Name: CLASS, dtype: float64

# %%
loctrans['PLANNING'].value_counts(normalize=True)
# Out:
# 1    0.830423
# 0    0.168695
# 4    0.000529
# 2    0.000235
# 9    0.000118
# Name: PLANNING, dtype: float64
