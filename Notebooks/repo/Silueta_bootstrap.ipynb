# %% [markdown]
# <a href="https://colab.research.google.com/github/rjnakano/manejo-inventarios-pdg/blob/main/Notebooks/repo/Silueta_bootstrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade kmodes
# Out:
# Requirement already up-to-date: kmodes in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from kmodes) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.13.3 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.0.1)

# %%
import pathlib
import pandas as pd
import numpy as np

# scikit-learn bootstrap
from sklearn.utils import resample
from sklearn.metrics import silhouette_score
from kmodes.kprototypes import KPrototypes

# %%
if str(pathlib.Path().absolute()).find('content') >= 0:
    sourcepath = 'https://raw.githubusercontent.com/rjnakano/manejo-inventarios-pdg/main/Datos/Transformed'
else:
    sourcepath = '../Datos/Transformed'
print(sourcepath)
# Out:
# https://raw.githubusercontent.com/rjnakano/manejo-inventarios-pdg/main/Datos/Transformed

# %%
# Lee dataset estandarizado de transacciones
data1 = pd.read_csv("{}/transacciones.csv".format(sourcepath))

# %%
data1['AISLE']=data1['AISLE'].astype(str)

# %%
data1.dtypes
# Out:
# AISLE        object
# IG           object
# HTS          object
# PLANNING     object
# ABC          object
# UOM          object
# CAT          object
# COSTX       float64
# QTYVAR      float64
# dtype: object

# %%
data1.head(5)
# Out:
#   AISLE    IG     HTS PLANNING ABC UOM    CAT     COSTX    QTYVAR
# 0    17  IG56  HTS119      1/1   B  PC  CAT17 -0.029976 -0.053250
# 1    17  IG56  HTS119      1/1   B  PC  CAT17  0.092472 -0.022999
# 2    17  IG56  HTS119      1/1   C  PC  CAT17  0.266130  0.004373
# 3    17  IG56  HTS119      1/1   B  PC  CAT17 -0.025112 -0.060323
# 4    15  IG56  HTS119      1/1   C  PC  CAT17 -0.077982 -0.062534

# %% [markdown]
# La versión original del código lee la matriz de distancias previamente calculada desde Google Drive o desde un archivo local en el PC según donde se encuentre almacenada.
#
# Desafortunadamente el archivo pesa cerca de 5 GB (matriz 16239 x 16239) y GitHub no permite archivos mayores a 100 MB. Por lo tanto se procede a recalcularla a continuación utilizando numba para optimización de desempeño.

# %%
# dm = pd.read_csv("/content/gdrive/MyDrive/distancias.csv")

# %%
# Posición de las variables categóricas
catColumnsPos = [data1.columns.get_loc(col) for col in list(data1.select_dtypes('object').columns)]
print('Categorical columns : {}'.format(list(data1.select_dtypes('object').columns)))
print('Categorical columns position : {}'.format(catColumnsPos))
# Out:
# Categorical columns : ['AISLE', 'IG', 'HTS', 'PLANNING', 'ABC', 'UOM', 'CAT']
# Categorical columns position : [0, 1, 2, 3, 4, 5, 6]

# %%
# Posición de las variables numéricas]
numColumnsPos = [data1.columns.get_loc(col) for col in list(data1.select_dtypes('float64').columns)]
print('Numerical columns : {}'.format(list(data1.select_dtypes('float64').columns)))
print('Numerical columns position : {}'.format(numColumnsPos))
# Out:
# Numerical columns : ['COSTX', 'QTYVAR']
# Numerical columns position : [7, 8]

# %%
import numba as nb
import time

# %%
data1.reset_index(drop=True)
N = data1.shape[0]

dataNum= data1.iloc[:,numColumnsPos]
dataNum=dataNum.to_numpy()

dataCat=data1.iloc[:,catColumnsPos]
dataCat=dataCat.to_numpy()

# gamma = 0.5 (constante)
catWeight=0.5

start_time = time.time()

# %%
@nb.njit
def dist_num_njit(data):
    distancias = np.zeros((len(data),len(data)), dtype=np.float64)
    valor = nb.float64(0)

    for i in range(len(data)):
        for j in range(i+1, len(data)):
            valor = nb.float64(np.sum((data[i] - data[j]) ** 2))
            distancias[i][j] = valor
    return distancias

# %%
def dist_cat(data, catWeight):
    distancias = np.zeros((len(data),len(data)), dtype=np.float64)
    for i in range(len(data)):
        for j in range(i+1, len(data)):
            distancias[i][j] = np.float64(np.sum(data[i]!=data[j])*catWeight)
    return distancias

# %%
@nb.njit
def traspose_njit (data):
    distancias = data
    for i in range(len(data)):
        for j in range(1+i,len(data)):
            distancias[j][i] = distancias[i][j]
    return distancias

# %%
# Todavía no está implementado correctamente
def get_scores(data,catWeight):
    # %time dist_num_np = dist_num_njit(dataNum[range(i)])
    # %time dist_cat_np = dist_cat(dataCat[range(i)], catWeight)
    # %time dm = np.sum([dist_cat_np, dist_num_np], axis=0)
    # %time dm = traspose_njit(dm)

# %%
start_time = time.time()
for i in [10, dataNum.shape[0]]:
  print('Número de filas a procesar: {}'.format(i))
  # %time dist_num_np = dist_num_njit(dataNum[range(i)])
  # %time dist_cat_np = dist_cat(dataCat[range(i)], catWeight)
  # %time dm = np.sum([dist_cat_np, dist_num_np], axis=0)
  # %time dm = traspose_njit(dm)
  print()
print('Tiempo total = {}'.format(time.time() - start_time))
# Out:
# Número de filas a procesar: 10
# CPU times: user 781 ms, sys: 20 ms, total: 801 ms
# Wall time: 784 ms
# CPU times: user 727 µs, sys: 0 ns, total: 727 µs
# Wall time: 733 µs
# CPU times: user 98 µs, sys: 0 ns, total: 98 µs
# Wall time: 102 µs
# CPU times: user 148 ms, sys: 0 ns, total: 148 ms
# Wall time: 147 ms
#
# Número de filas a procesar: 16239
# CPU times: user 16.9 s, sys: 1.04 s, total: 17.9 s
# Wall time: 17.7 s
# CPU times: user 26min 17s, sys: 5.43 s, total: 26min 22s
# Wall time: 26min 18s
# CPU times: user 1.83 s, sys: 1.34 s, total: 3.17 s
# Wall time: 3.15 s
# CPU times: user 1.4 s, sys: 12.1 ms, total: 1.41 s
# Wall time: 1.39 s
#
# Tiempo total = 1601.8853166103363

# %% [markdown]
# **Algoritmo Silueta Bootstrap**

# %%
import time
start_time = time.time()
# Coeficiente silueta para K 2-4
kValues = [2, 3, 4]
gamma = 0.5
nBootstrap = 100
# Inicializamos la matriz de coeficientes silueta con ceros
silueta = [ [ 0 for j in range(nBootstrap + 1) ] for i in range(len(kValues)) ]
catColumnsPos = [data1.columns.get_loc(col) for col in list(data1.select_dtypes('object').columns)]
N = data1.shape[0]

# %%
for k in kValues:
  print('Dataset original, k = ', k)
  kprototype = KPrototypes(n_jobs = -1, n_clusters = k, init = 'Huang', gamma = gamma, random_state = 0)
  kprototype.fit_predict(data1, categorical = catColumnsPos)
  print("--- %s seconds ---" % (time.time() - start_time))
  silueta[k-min(kValues)][0] = silhouette_score(dm, kprototype.labels_, metric='precomputed')
  print("Coeficiente silueta --- %s seconds ---" % (time.time() - start_time))
  print(silueta[k-min(kValues)][0])

for b in range(1,nBootstrap+1):
  scores = np.zeros((len(data1),len(data1)), dtype=np.float64)
  print('bootstrap # ',b);
  boot = resample(data1, replace=True, n_samples=N, random_state=b)
  bootIndex = boot.index
  for i in range(N):
    for j in range(i+1,N):
      scores[i][j]=dm[bootIndex[i]][bootIndex[j]]
  print("Matriz de distancias (triangulo superior) --- %s seconds ---" % (time.time() - start_time))
  # Completamos la matriz
  for i in range(0,N):
    for j in range(0,i):
      scores[i][j]=scores[j][i]
  print("Espejo --- %s seconds ---" % (time.time() - start_time))
  for k in kValues:
    print('Bootstrap, k = ', k)
    kprototypebs = KPrototypes(n_jobs = -1, n_clusters = k, init = 'Huang', gamma = gamma, random_state = 1)
    kprototypebs.fit_predict(boot, categorical = catColumnsPos)
    print("--- %s seconds ---" % (time.time() - start_time));
    silueta[k-min(kValues)][b] = silhouette_score(scores, kprototypebs.labels_, metric='precomputed')
    print("Coeficiente silueta --- %s seconds ---" % (time.time() - start_time))
    print(silueta[k-min(kValues)][b])
# Out:
# Dataset original, k =  2
# --- 80.45178961753845 seconds ---
# Coeficiente silueta --- 83.46208024024963 seconds ---
# 0.7368588147337156
# Dataset original, k =  3
# --- 171.46498107910156 seconds ---
# Coeficiente silueta --- 174.4525866508484 seconds ---
# 0.7182825853232915
# Dataset original, k =  4
# --- 259.15191531181335 seconds ---
# Coeficiente silueta --- 261.9385132789612 seconds ---
# 0.10914930712265486
# bootstrap #  1
# Matriz de distancias (triangulo superior) --- 606.0396528244019 seconds ---
# Espejo --- 716.2900447845459 seconds ---
# Bootstrap, k =  2
# --- 782.3157691955566 seconds ---
# Coeficiente silueta --- 784.1398751735687 seconds ---
# 0.7853497277166785
# Bootstrap, k =  3
# --- 878.8913578987122 seconds ---
# Coeficiente silueta --- 880.6931409835815 seconds ---
# 0.7989985671062392
# Bootstrap, k =  4
# --- 981.536144733429 seconds ---
# Coeficiente silueta --- 982.9725198745728 seconds ---
# 0.129275946751179
# bootstrap #  2
# Matriz de distancias (triangulo superior) --- 1326.0416538715363 seconds ---
# Espejo --- 1433.762841463089 seconds ---
# Bootstrap, k =  2
# --- 1500.5542964935303 seconds ---
# Coeficiente silueta --- 1502.4058363437653 seconds ---
# 0.7482421177367857
# Bootstrap, k =  3
# --- 1591.909926891327 seconds ---
# Coeficiente silueta --- 1593.3748393058777 seconds ---
# 0.059264681470129074
# Bootstrap, k =  4
# --- 1684.6529822349548 seconds ---
# Coeficiente silueta --- 1686.483494758606 seconds ---
# 0.7575698112560354
# bootstrap #  3
# Matriz de distancias (triangulo superior) --- 2032.2719371318817 seconds ---
# Espejo --- 2141.4338178634644 seconds ---
# Bootstrap, k =  2
# --- 2197.7301473617554 seconds ---
# Coeficiente silueta --- 2199.5459022521973 seconds ---
# 0.7832966669137054
# Bootstrap, k =  3
# --- 2298.8868074417114 seconds ---
# Coeficiente silueta --- 2300.3597021102905 seconds ---
# 0.1040257872189396
# Bootstrap, k =  4
# --- 2399.7083756923676 seconds ---
# Coeficiente silueta --- 2401.167432785034 seconds ---
# 0.12761437270570103
# bootstrap #  4
# Matriz de distancias (triangulo superior) --- 2747.0241639614105 seconds ---
# Espejo --- 2856.7239162921906 seconds ---
# Bootstrap, k =  2
# --- 2918.707539796829 seconds ---
# Coeficiente silueta --- 2920.5519721508026 seconds ---
# 0.7671036562665906
# Bootstrap, k =  3
# --- 3015.0048513412476 seconds ---
# Coeficiente silueta --- 3016.473931312561 seconds ---
# 0.09730916259304075
# Bootstrap, k =  4
# --- 3113.284346342087 seconds ---
# Coeficiente silueta --- 3114.7563037872314 seconds ---
# 0.12470297678953488
# bootstrap #  5
# Matriz de distancias (triangulo superior) --- 3460.348162651062 seconds ---
# Espejo --- 3569.0125799179077 seconds ---
# Bootstrap, k =  2
# --- 3631.9609842300415 seconds ---
# Coeficiente silueta --- 3633.8282203674316 seconds ---
# 0.8838183711330552
# Bootstrap, k =  3
# --- 3737.8360302448273 seconds ---
# Coeficiente silueta --- 3739.6351296901703 seconds ---
# 0.7639035358264514
# Bootstrap, k =  4
# --- 3838.97571349144 seconds ---
# Coeficiente silueta --- 3840.7666041851044 seconds ---
# 0.7608427724454497
# bootstrap #  6
# Matriz de distancias (triangulo superior) --- 4185.98757481575 seconds ---
# Espejo --- 4295.182044506073 seconds ---
# Bootstrap, k =  2
# --- 4355.431008815765 seconds ---
# Coeficiente silueta --- 4357.27108168602 seconds ---
# 0.7329651073838298
# Bootstrap, k =  3
# --- 4444.413768053055 seconds ---
# Coeficiente silueta --- 4446.219452857971 seconds ---
# 0.7794700736395734
# Bootstrap, k =  4
# --- 4530.157903671265 seconds ---
# Coeficiente silueta --- 4531.660482168198 seconds ---
# 0.13736943006341173
# bootstrap #  7
# Matriz de distancias (triangulo superior) --- 4883.3430914878845 seconds ---
# Espejo --- 4994.838861703873 seconds ---
# Bootstrap, k =  2
# --- 5059.282394886017 seconds ---
# Coeficiente silueta --- 5061.099047422409 seconds ---
# 0.7346974415405396
# Bootstrap, k =  3
# --- 5156.552258968353 seconds ---
# Coeficiente silueta --- 5158.009213447571 seconds ---
# 0.10645341393133423
# Bootstrap, k =  4
# --- 5248.970561504364 seconds ---
# Coeficiente silueta --- 5250.399369716644 seconds ---
# 0.12596327203895838
# bootstrap #  8
# Matriz de distancias (triangulo superior) --- 5591.600549459457 seconds ---
# Espejo --- 5699.288382053375 seconds ---
# Bootstrap, k =  2
# --- 5762.943148136139 seconds ---
# Coeficiente silueta --- 5764.7604558467865 seconds ---
# 0.761246574839105
# Bootstrap, k =  3
# --- 5853.699814319611 seconds ---
# Coeficiente silueta --- 5855.143293619156 seconds ---
# 0.09194885851650635
# Bootstrap, k =  4
# --- 5952.594753503799 seconds ---
# Coeficiente silueta --- 5954.039018630981 seconds ---
# 0.12310112710945272
# bootstrap #  9
# Matriz de distancias (triangulo superior) --- 6296.798198223114 seconds ---
# Espejo --- 6407.164824962616 seconds ---
# Bootstrap, k =  2
# --- 6466.694455862045 seconds ---
# Coeficiente silueta --- 6468.49681687355 seconds ---
# 0.7349112837408743
# Bootstrap, k =  3
# --- 6557.397793531418 seconds ---
# Coeficiente silueta --- 6558.847660779953 seconds ---
# 0.06901626134845709
# Bootstrap, k =  4
# --- 6656.117154598236 seconds ---
# Coeficiente silueta --- 6657.888596773148 seconds ---
# 0.7635561459924977
# bootstrap #  10
# Matriz de distancias (triangulo superior) --- 6996.2231957912445 seconds ---
# Espejo --- 7105.1770622730255 seconds ---
# Bootstrap, k =  2
# --- 7163.253834247589 seconds ---
# Coeficiente silueta --- 7165.101446628571 seconds ---
# 0.8890682310677279
# Bootstrap, k =  3
# --- 7259.308570146561 seconds ---
# Coeficiente silueta --- 7261.102583646774 seconds ---
# 0.77932543883099
# Bootstrap, k =  4
# --- 7347.745035409927 seconds ---
# Coeficiente silueta --- 7349.517187595367 seconds ---
# 0.7637650787727309
# bootstrap #  11
# Matriz de distancias (triangulo superior) --- 7691.474676370621 seconds ---
# Espejo --- 7798.722328424454 seconds ---
# Bootstrap, k =  2
# --- 7860.354437351227 seconds ---
# Coeficiente silueta --- 7862.168703079224 seconds ---
# 0.7480638023417062
# Bootstrap, k =  3
# --- 7952.92768907547 seconds ---
# Coeficiente silueta --- 7954.3725073337555 seconds ---
# 0.10313270193621578
# Bootstrap, k =  4
# --- 8039.623836755753 seconds ---
# Coeficiente silueta --- 8041.057262420654 seconds ---
# 0.12356331283355504
# bootstrap #  12
# Matriz de distancias (triangulo superior) --- 8376.27418923378 seconds ---
# Espejo --- 8486.030748605728 seconds ---
# Bootstrap, k =  2
# --- 8549.618216514587 seconds ---
# Coeficiente silueta --- 8551.433683633804 seconds ---
# 0.7431633142600728
# Bootstrap, k =  3
# --- 8633.548754692078 seconds ---
# Coeficiente silueta --- 8635.341646671295 seconds ---
# 0.7889528153769771
# Bootstrap, k =  4
# --- 8748.907221078873 seconds ---
# Coeficiente silueta --- 8750.396609783173 seconds ---
# 0.13409610678046613
# bootstrap #  13
# Matriz de distancias (triangulo superior) --- 9086.772237062454 seconds ---
# Espejo --- 9197.123939990997 seconds ---
# Bootstrap, k =  2
# --- 9261.631654024124 seconds ---
# Coeficiente silueta --- 9263.475299835205 seconds ---
# 0.7282019664354878
# Bootstrap, k =  3
# --- 9357.405338048935 seconds ---
# Coeficiente silueta --- 9358.839503288269 seconds ---
# 0.07951988807997419
# Bootstrap, k =  4
# --- 9441.187295675278 seconds ---
# Coeficiente silueta --- 9442.670179128647 seconds ---
# 0.13736047552691674
# bootstrap #  14
# Matriz de distancias (triangulo superior) --- 9785.92318868637 seconds ---
# Espejo --- 9896.263659238815 seconds ---
# Bootstrap, k =  2
# --- 9962.033363819122 seconds ---
# Coeficiente silueta --- 9963.854551792145 seconds ---
# 0.7037038384113625
# Bootstrap, k =  3
# --- 10067.695495128632 seconds ---
# Coeficiente silueta --- 10069.544189691544 seconds ---
# 0.7814576238783323
# Bootstrap, k =  4
# --- 10164.019681930542 seconds ---
# Coeficiente silueta --- 10165.79680633545 seconds ---
# 0.7527134886157045
# bootstrap #  15
# Matriz de distancias (triangulo superior) --- 10512.27101111412 seconds ---
# Espejo --- 10622.49331665039 seconds ---
# Bootstrap, k =  2
# --- 10684.541204929352 seconds ---
# Coeficiente silueta --- 10686.392946243286 seconds ---
# 0.7801358595391128
# Bootstrap, k =  3
# --- 10783.354901790619 seconds ---
# Coeficiente silueta --- 10784.834376096725 seconds ---
# 0.08430129841563423
# Bootstrap, k =  4
# --- 10897.892132520676 seconds ---
# Coeficiente silueta --- 10899.340402126312 seconds ---
# 0.09455759219236033
# bootstrap #  16
# Matriz de distancias (triangulo superior) --- 11251.717867136002 seconds ---
# Espejo --- 11360.947867631912 seconds ---
# Bootstrap, k =  2
# --- 11420.805723428726 seconds ---
# Coeficiente silueta --- 11422.703995466232 seconds ---
# 0.7814841135230655
# Bootstrap, k =  3
# --- 11518.717538118362 seconds ---
# Coeficiente silueta --- 11520.210970878601 seconds ---
# 0.10518405304502634
# Bootstrap, k =  4
# --- 11619.312918186188 seconds ---
# Coeficiente silueta --- 11620.825409889221 seconds ---
# 0.1274312534016999
# bootstrap #  17
# Matriz de distancias (triangulo superior) --- 11971.635277748108 seconds ---
# Espejo --- 12082.903667926788 seconds ---
# Bootstrap, k =  2
# --- 12147.65250825882 seconds ---
# Coeficiente silueta --- 12149.137797117233 seconds ---
# 0.07468520892481585
# Bootstrap, k =  3
# --- 12270.597249031067 seconds ---
# Coeficiente silueta --- 12272.422873735428 seconds ---
# 0.7718221876506196
# Bootstrap, k =  4
# --- 12377.457926034927 seconds ---
# Coeficiente silueta --- 12378.946879863739 seconds ---
# 0.13726054953760616
# bootstrap #  18
# Matriz de distancias (triangulo superior) --- 12726.068830013275 seconds ---
# Espejo --- 12836.996103286743 seconds ---
# Bootstrap, k =  2
# --- 12900.350761651993 seconds ---
# Coeficiente silueta --- 12902.225423336029 seconds ---
# 0.7816656383178576
# Bootstrap, k =  3
# --- 12986.580847978592 seconds ---
# Coeficiente silueta --- 12988.06820988655 seconds ---
# 0.08398091218196965
# Bootstrap, k =  4
# --- 13111.990357875824 seconds ---
# Coeficiente silueta --- 13113.779410123825 seconds ---
# 0.7491854537636675
# bootstrap #  19
# Matriz de distancias (triangulo superior) --- 13455.598270893097 seconds ---
# Espejo --- 13568.45715045929 seconds ---
# Bootstrap, k =  2
# --- 13637.443496704102 seconds ---
# Coeficiente silueta --- 13639.314455986023 seconds ---
# 0.7424963508081259
# Bootstrap, k =  3
# --- 13743.714695215225 seconds ---
# Coeficiente silueta --- 13745.172001123428 seconds ---
# 0.09017521740538716
# Bootstrap, k =  4
# --- 13859.590700864792 seconds ---
# Coeficiente silueta --- 13861.400142908096 seconds ---
# 0.7364677236426879
# bootstrap #  20
# Matriz de distancias (triangulo superior) --- 14204.774138450623 seconds ---
# Espejo --- 14316.369969367981 seconds ---
# Bootstrap, k =  2
# --- 14381.180123567581 seconds ---
# Coeficiente silueta --- 14383.046614408493 seconds ---
# 0.7651292306439248
# Bootstrap, k =  3
# --- 14480.60288143158 seconds ---
# Coeficiente silueta --- 14482.069799423218 seconds ---
# 0.09749538919756613
# Bootstrap, k =  4
# --- 14581.721057653427 seconds ---
# Coeficiente silueta --- 14583.165980100632 seconds ---
# 0.12394052565059635
# bootstrap #  21
# Matriz de distancias (triangulo superior) --- 14933.643414258957 seconds ---
# Espejo --- 15043.20709681511 seconds ---
# Bootstrap, k =  2
# --- 15096.437651395798 seconds ---
# Coeficiente silueta --- 15098.2567923069 seconds ---
# 0.89898854169004
# Bootstrap, k =  3
# --- 15191.756076574326 seconds ---
# Coeficiente silueta --- 15193.206184864044 seconds ---
# 0.0748131515813479
# Bootstrap, k =  4
# --- 15312.171423435211 seconds ---
# Coeficiente silueta --- 15313.9592461586 seconds ---
# 0.7909310030136812
# bootstrap #  22
# Matriz de distancias (triangulo superior) --- 15660.930935382843 seconds ---
# Espejo --- 15772.496000051498 seconds ---
# Bootstrap, k =  2
# --- 15845.947035312653 seconds ---
# Coeficiente silueta --- 15847.782541513443 seconds ---
# 0.7203303184073275
# Bootstrap, k =  3
# --- 15939.113463878632 seconds ---
# Coeficiente silueta --- 15940.574223518372 seconds ---
# 0.07823471440230047
# Bootstrap, k =  4
# --- 16022.236358642578 seconds ---
# Coeficiente silueta --- 16024.025921344757 seconds ---
# 0.7590267142392799
# bootstrap #  23
# Matriz de distancias (triangulo superior) --- 16370.397692918777 seconds ---
# Espejo --- 16483.072087287903 seconds ---
# Bootstrap, k =  2
# --- 16542.905935287476 seconds ---
# Coeficiente silueta --- 16544.383910655975 seconds ---
# 0.083700577493294
# Bootstrap, k =  3
# --- 16648.81337761879 seconds ---
# Coeficiente silueta --- 16650.273085594177 seconds ---
# 0.0890658305457619
# Bootstrap, k =  4
# --- 16754.783895015717 seconds ---
# Coeficiente silueta --- 16756.239010810852 seconds ---
# 0.11244635474116721
# bootstrap #  24
# Matriz de distancias (triangulo superior) --- 17099.525178194046 seconds ---
# Espejo --- 17208.8522503376 seconds ---
# Bootstrap, k =  2
# --- 17287.348918914795 seconds ---
# Coeficiente silueta --- 17289.139812469482 seconds ---
# 0.7539454798353602
# Bootstrap, k =  3
# --- 17380.056310415268 seconds ---
# Coeficiente silueta --- 17381.898661851883 seconds ---
# 0.7804585037701445
# Bootstrap, k =  4
# --- 17494.439106225967 seconds ---
# Coeficiente silueta --- 17495.89436364174 seconds ---
# 0.1111285664949042
# bootstrap #  25
# Matriz de distancias (triangulo superior) --- 17840.91827082634 seconds ---
# Espejo --- 17952.275037527084 seconds ---
# Bootstrap, k =  2
# --- 18014.921241283417 seconds ---
# Coeficiente silueta --- 18016.77778673172 seconds ---
# 0.7549856793769718
# Bootstrap, k =  3
# --- 18116.68452501297 seconds ---
# Coeficiente silueta --- 18118.134432315826 seconds ---
# 0.10157284451844308
# Bootstrap, k =  4
# --- 18213.921007871628 seconds ---
# Coeficiente silueta --- 18215.719563484192 seconds ---
# 0.7604704376256083
# bootstrap #  26
# Matriz de distancias (triangulo superior) --- 18565.158764362335 seconds ---
# Espejo --- 18674.23278617859 seconds ---
# Bootstrap, k =  2
# --- 18745.311363220215 seconds ---
# Coeficiente silueta --- 18747.134469747543 seconds ---
# 0.8989004380510246
# Bootstrap, k =  3
# --- 18880.959481954575 seconds ---
# Coeficiente silueta --- 18882.424735546112 seconds ---
# 0.12091336941410949
# Bootstrap, k =  4
# --- 19005.185230493546 seconds ---
# Coeficiente silueta --- 19006.645891189575 seconds ---
# 0.11260627246183327
# bootstrap #  27
# Matriz de distancias (triangulo superior) --- 19349.58646464348 seconds ---
# Espejo --- 19457.849730730057 seconds ---
# Bootstrap, k =  2
# --- 19518.232496738434 seconds ---
# Coeficiente silueta --- 19520.07275557518 seconds ---
# 0.7542055326779429
# Bootstrap, k =  3
# --- 19608.62532711029 seconds ---
# Coeficiente silueta --- 19610.07605957985 seconds ---
# 0.09058294883981537
# Bootstrap, k =  4
# --- 19704.12934112549 seconds ---
# Coeficiente silueta --- 19705.932436466217 seconds ---
# 0.7435730881977053
# bootstrap #  28
# Matriz de distancias (triangulo superior) --- 20052.275782585144 seconds ---
# Espejo --- 20164.712817192078 seconds ---
# Bootstrap, k =  2
# --- 20226.75209736824 seconds ---
# Coeficiente silueta --- 20228.24447107315 seconds ---
# 0.08255043340802451
# Bootstrap, k =  3
# --- 20324.6484208107 seconds ---
# Coeficiente silueta --- 20326.104300260544 seconds ---
# 0.09471198423948211
# Bootstrap, k =  4
# --- 20434.271582603455 seconds ---
# Coeficiente silueta --- 20435.74578142166 seconds ---
# 0.10094558813217726
# bootstrap #  29
# Matriz de distancias (triangulo superior) --- 20783.562668323517 seconds ---
# Espejo --- 20894.648773431778 seconds ---
# Bootstrap, k =  2
# --- 20964.4406645298 seconds ---
# Coeficiente silueta --- 20966.307866334915 seconds ---
# 0.718099741525469
# Bootstrap, k =  3
# --- 21078.300036668777 seconds ---
# Coeficiente silueta --- 21080.14401936531 seconds ---
# 0.7587674538782295
# Bootstrap, k =  4
# --- 21177.412248134613 seconds ---
# Coeficiente silueta --- 21179.23141169548 seconds ---
# 0.7453350519777425
# bootstrap #  30
# Matriz de distancias (triangulo superior) --- 21531.75694823265 seconds ---
# Espejo --- 21643.160221338272 seconds ---
# Bootstrap, k =  2
# --- 21705.695427417755 seconds ---
# Coeficiente silueta --- 21707.54819059372 seconds ---
# 0.7358077060215367
# Bootstrap, k =  3
# --- 21789.93870782852 seconds ---
# Coeficiente silueta --- 21791.419064760208 seconds ---
# 0.07752624708303278
# Bootstrap, k =  4
# --- 21883.475445985794 seconds ---
# Coeficiente silueta --- 21885.30848646164 seconds ---
# 0.7508931935720758
# bootstrap #  31
# Matriz de distancias (triangulo superior) --- 22237.493654966354 seconds ---
# Espejo --- 22349.855498075485 seconds ---
# Bootstrap, k =  2
# --- 22414.723518133163 seconds ---
# Coeficiente silueta --- 22416.55529332161 seconds ---
# 0.7681564360545858
# Bootstrap, k =  3
# --- 22514.009870767593 seconds ---
# Coeficiente silueta --- 22515.493848323822 seconds ---
# 0.09702657305221157
# Bootstrap, k =  4
# --- 22601.396483898163 seconds ---
# Coeficiente silueta --- 22602.852755069733 seconds ---
# 0.12309906455285655
# bootstrap #  32
# Matriz de distancias (triangulo superior) --- 22950.13550233841 seconds ---
# Espejo --- 23060.888054847717 seconds ---
# Bootstrap, k =  2
# --- 23119.53636074066 seconds ---
# Coeficiente silueta --- 23121.38283777237 seconds ---
# 0.7521815139745293
# Bootstrap, k =  3
# --- 23211.824579954147 seconds ---
# Coeficiente silueta --- 23213.296157836914 seconds ---
# 0.09553264820649976
# Bootstrap, k =  4
# --- 23300.310160160065 seconds ---
# Coeficiente silueta --- 23302.11876821518 seconds ---
# 0.7675613181408637
# bootstrap #  33
# Matriz de distancias (triangulo superior) --- 23643.226796627045 seconds ---
# Espejo --- 23754.181821346283 seconds ---
# Bootstrap, k =  2
# --- 23819.712847709656 seconds ---
# Coeficiente silueta --- 23821.54078221321 seconds ---
# 0.7377623769350677
# Bootstrap, k =  3
# --- 23918.243564367294 seconds ---
# Coeficiente silueta --- 23919.671914339066 seconds ---
# 0.09330431975480886
# Bootstrap, k =  4
# --- 24010.426402568817 seconds ---
# Coeficiente silueta --- 24012.217987537384 seconds ---
# 0.7456822549081186
# bootstrap #  34
# Matriz de distancias (triangulo superior) --- 24351.009473323822 seconds ---
# Espejo --- 24459.260593414307 seconds ---
# Bootstrap, k =  2
# --- 24522.317444324493 seconds ---
# Coeficiente silueta --- 24524.120807170868 seconds ---
# 0.7274999074889235
# Bootstrap, k =  3
# --- 24617.158878564835 seconds ---
# Coeficiente silueta --- 24618.963361501694 seconds ---
# 0.7719039761824326
# Bootstrap, k =  4
# --- 24719.90507221222 seconds ---
# Coeficiente silueta --- 24721.69693350792 seconds ---
# 0.760837404444334
# bootstrap #  35
# Matriz de distancias (triangulo superior) --- 25058.832606077194 seconds ---
# Espejo --- 25168.6278591156 seconds ---
# Bootstrap, k =  2
# --- 25227.053934574127 seconds ---
# Coeficiente silueta --- 25228.848213672638 seconds ---
# 0.7239272130768715
# Bootstrap, k =  3
# --- 25316.87803030014 seconds ---
# Coeficiente silueta --- 25318.33465886116 seconds ---
# 0.08143681706336275
# Bootstrap, k =  4
# --- 25408.713879346848 seconds ---
# Coeficiente silueta --- 25410.52167916298 seconds ---
# 0.7510889048695442
# bootstrap #  36
# Matriz de distancias (triangulo superior) --- 25753.44771027565 seconds ---
# Espejo --- 25864.307703971863 seconds ---
# Bootstrap, k =  2
# --- 25924.504809617996 seconds ---
# Coeficiente silueta --- 25926.316765785217 seconds ---
# 0.7236563479375415
# Bootstrap, k =  3
# --- 26001.988733291626 seconds ---
# Coeficiente silueta --- 26003.447615861893 seconds ---
# 0.07637174377468804
# Bootstrap, k =  4
# --- 26090.692989826202 seconds ---
# Coeficiente silueta --- 26092.175615787506 seconds ---
# 0.14469984822168092
# bootstrap #  37
# Matriz de distancias (triangulo superior) --- 26428.566539525986 seconds ---
# Espejo --- 26536.977439165115 seconds ---
# Bootstrap, k =  2
# --- 26598.87773656845 seconds ---
# Coeficiente silueta --- 26600.70616722107 seconds ---
# 0.9126127303879418
# Bootstrap, k =  3
# --- 26697.8273229599 seconds ---
# Coeficiente silueta --- 26699.25781607628 seconds ---
# 0.07974836929417704
# Bootstrap, k =  4
# --- 26787.123971939087 seconds ---
# Coeficiente silueta --- 26788.914492607117 seconds ---
# 0.7885325855089561
# bootstrap #  38
# Matriz de distancias (triangulo superior) --- 27129.35459470749 seconds ---
# Espejo --- 27236.826631069183 seconds ---
# Bootstrap, k =  2
# --- 27318.015906095505 seconds ---
# Coeficiente silueta --- 27319.8644387722 seconds ---
# 0.9987909799547332
# Bootstrap, k =  3
# --- 27421.667741060257 seconds ---
# Coeficiente silueta --- 27423.106049776077 seconds ---
# 0.11670678660291997
# Bootstrap, k =  4
# --- 27505.907366752625 seconds ---
# Coeficiente silueta --- 27507.380242824554 seconds ---
# 0.14034132758022666
# bootstrap #  39
# Matriz de distancias (triangulo superior) --- 27853.091824293137 seconds ---
# Espejo --- 27963.78888630867 seconds ---
# Bootstrap, k =  2
# --- 28027.51287007332 seconds ---
# Coeficiente silueta --- 28029.33652305603 seconds ---
# 0.7565621365694528
# Bootstrap, k =  3
# --- 28130.733780145645 seconds ---
# Coeficiente silueta --- 28132.207961797714 seconds ---
# 0.11257305191562955
# Bootstrap, k =  4
# --- 28230.784024953842 seconds ---
# Coeficiente silueta --- 28232.20822405815 seconds ---
# 0.13082379005881908
# bootstrap #  40
# Matriz de distancias (triangulo superior) --- 28575.906864881516 seconds ---
# Espejo --- 28685.855687379837 seconds ---
# Bootstrap, k =  2
# --- 28743.862521648407 seconds ---
# Coeficiente silueta --- 28745.692560195923 seconds ---
# 0.7654160534604825
# Bootstrap, k =  3
# --- 28836.716141462326 seconds ---
# Coeficiente silueta --- 28838.172827482224 seconds ---
# 0.09663271467450336
# Bootstrap, k =  4
# --- 28933.768408298492 seconds ---
# Coeficiente silueta --- 28935.575873851776 seconds ---
# 0.7298121692268988
# bootstrap #  41
# Matriz de distancias (triangulo superior) --- 29282.051371335983 seconds ---
# Espejo --- 29392.803889513016 seconds ---
# Bootstrap, k =  2
# --- 29452.53353047371 seconds ---
# Coeficiente silueta --- 29454.367766857147 seconds ---
# 0.8931401797491474
# Bootstrap, k =  3
# --- 29555.681681632996 seconds ---
# Coeficiente silueta --- 29557.47521185875 seconds ---
# 0.783239470106952
# Bootstrap, k =  4
# --- 29642.493950366974 seconds ---
# Coeficiente silueta --- 29644.290720701218 seconds ---
# 0.7756959076700607
# bootstrap #  42
# Matriz de distancias (triangulo superior) --- 29989.96018266678 seconds ---
# Espejo --- 30099.190290927887 seconds ---
# Bootstrap, k =  2
# --- 30162.779021024704 seconds ---
# Coeficiente silueta --- 30164.60956311226 seconds ---
# 0.7370834963269638
# Bootstrap, k =  3
# --- 30258.671271800995 seconds ---
# Coeficiente silueta --- 30260.118953943253 seconds ---
# 0.08400897349737028
# Bootstrap, k =  4
# --- 30357.133896112442 seconds ---
# Coeficiente silueta --- 30358.941170692444 seconds ---
# 0.7662004938738511
# bootstrap #  43
# Matriz de distancias (triangulo superior) --- 30706.989680051804 seconds ---
# Espejo --- 30818.569341897964 seconds ---
# Bootstrap, k =  2
# --- 30880.67876791954 seconds ---
# Coeficiente silueta --- 30882.52737903595 seconds ---
# 0.7571996585084391
# Bootstrap, k =  3
# --- 30968.470569372177 seconds ---
# Coeficiente silueta --- 30969.942796707153 seconds ---
# 0.07775034238495405
# Bootstrap, k =  4
# --- 31062.317038297653 seconds ---
# Coeficiente silueta --- 31064.08812403679 seconds ---
# 0.7484095539044135
# bootstrap #  44
# Matriz de distancias (triangulo superior) --- 31412.23430132866 seconds ---
# Espejo --- 31522.3992292881 seconds ---
# Bootstrap, k =  2
# --- 31585.298240184784 seconds ---
# Coeficiente silueta --- 31587.13063764572 seconds ---
# 0.7154738841153138
# Bootstrap, k =  3
# --- 31671.788871765137 seconds ---
# Coeficiente silueta --- 31673.61840081215 seconds ---
# 0.7736565871009178
# Bootstrap, k =  4
# --- 31767.83259677887 seconds ---
# Coeficiente silueta --- 31769.642826080322 seconds ---
# 0.7787122831292347
# bootstrap #  45
# Matriz de distancias (triangulo superior) --- 32108.816650867462 seconds ---
# Espejo --- 32217.657232046127 seconds ---
# Bootstrap, k =  2
# --- 32280.357427597046 seconds ---
# Coeficiente silueta --- 32282.171033859253 seconds ---
# 0.7633711254503979
# Bootstrap, k =  3
# --- 32377.500888824463 seconds ---
# Coeficiente silueta --- 32378.947971582413 seconds ---
# 0.09953076711275372
# Bootstrap, k =  4
# --- 32472.8226685524 seconds ---
# Coeficiente silueta --- 32474.602965831757 seconds ---
# 0.723730252884611
# bootstrap #  46
# Matriz de distancias (triangulo superior) --- 32813.32636976242 seconds ---
# Espejo --- 32920.3577542305 seconds ---
# Bootstrap, k =  2
# --- 32976.777116537094 seconds ---
# Coeficiente silueta --- 32978.565729379654 seconds ---
# 0.6960313873768464
# Bootstrap, k =  3
# --- 33055.38666510582 seconds ---
# Coeficiente silueta --- 33057.167672634125 seconds ---
# 0.7680609933940777
# Bootstrap, k =  4
# --- 33144.06654214859 seconds ---
# Coeficiente silueta --- 33145.84040904045 seconds ---
# 0.7708863000832036
# bootstrap #  47
# Matriz de distancias (triangulo superior) --- 33482.13411569595 seconds ---
# Espejo --- 33590.53468608856 seconds ---
# Bootstrap, k =  2
# --- 33652.70099782944 seconds ---
# Coeficiente silueta --- 33654.50999188423 seconds ---
# 0.7748675502753988
# Bootstrap, k =  3
# --- 33759.080305337906 seconds ---
# Coeficiente silueta --- 33760.530760765076 seconds ---
# 0.10562021143822592
# Bootstrap, k =  4
# --- 33867.44968485832 seconds ---
# Coeficiente silueta --- 33868.90414977074 seconds ---
# 0.12460953502670753
# bootstrap #  48
# Matriz de distancias (triangulo superior) --- 34205.62564754486 seconds ---
# Espejo --- 34312.98778796196 seconds ---
# Bootstrap, k =  2
# --- 34370.595941782 seconds ---
# Coeficiente silueta --- 34372.48546886444 seconds ---
# 0.8934451371227542
# Bootstrap, k =  3
# --- 34469.409071445465 seconds ---
# Coeficiente silueta --- 34470.89196872711 seconds ---
# 0.07521243550903678
# Bootstrap, k =  4
# --- 34548.91889810562 seconds ---
# Coeficiente silueta --- 34550.4000415802 seconds ---
# 0.1342288274095251
# bootstrap #  49
# Matriz de distancias (triangulo superior) --- 34892.00958585739 seconds ---
# Espejo --- 35001.58418893814 seconds ---
# Bootstrap, k =  2
# --- 35068.519602537155 seconds ---
# Coeficiente silueta --- 35070.356110572815 seconds ---
# 0.721542113729111
# Bootstrap, k =  3
# --- 35158.655552864075 seconds ---
# Coeficiente silueta --- 35160.11650490761 seconds ---
# 0.08851348126435622
# Bootstrap, k =  4
# --- 35265.79042124748 seconds ---
# Coeficiente silueta --- 35267.60200929642 seconds ---
# 0.72589827672556
# bootstrap #  50
# Matriz de distancias (triangulo superior) --- 35613.72645068169 seconds ---
# Espejo --- 35721.63727045059 seconds ---
# Bootstrap, k =  2
# --- 35791.50733113289 seconds ---
# Coeficiente silueta --- 35793.3430557251 seconds ---
# 0.7498716995241181
# Bootstrap, k =  3
# --- 35882.14039731026 seconds ---
# Coeficiente silueta --- 35883.60366821289 seconds ---
# 0.09221899426852445
# Bootstrap, k =  4
# --- 35972.86591172218 seconds ---
# Coeficiente silueta --- 35974.64719867706 seconds ---
# 0.7541844062923474
# bootstrap #  51
# Matriz de distancias (triangulo superior) --- 36315.310269355774 seconds ---
# Espejo --- 36424.04133820534 seconds ---
# Bootstrap, k =  2
# --- 36489.95035648346 seconds ---
# Coeficiente silueta --- 36491.78286528587 seconds ---
# 0.7481945657678041
# Bootstrap, k =  3
# --- 36600.528034210205 seconds ---
# Coeficiente silueta --- 36602.00488591194 seconds ---
# 0.09061682211134096
# Bootstrap, k =  4
# --- 36696.15426158905 seconds ---
# Coeficiente silueta --- 36697.97143101692 seconds ---
# 0.7355630126937776
# bootstrap #  52
# Matriz de distancias (triangulo superior) --- 37040.40143418312 seconds ---
# Espejo --- 37149.504378557205 seconds ---
# Bootstrap, k =  2
# --- 37218.01252365112 seconds ---
# Coeficiente silueta --- 37219.88631248474 seconds ---
# 0.75679157798133
# Bootstrap, k =  3
# --- 37314.191831588745 seconds ---
# Coeficiente silueta --- 37315.647297382355 seconds ---
# 0.08127899563567553
# Bootstrap, k =  4
# --- 37402.46404528618 seconds ---
# Coeficiente silueta --- 37404.27998685837 seconds ---
# 0.7455415952497496
# bootstrap #  53
# Matriz de distancias (triangulo superior) --- 37747.35892915726 seconds ---
# Espejo --- 37856.398825883865 seconds ---
# Bootstrap, k =  2
# --- 37923.471363544464 seconds ---
# Coeficiente silueta --- 37925.285125494 seconds ---
# 0.9001461569814482
# Bootstrap, k =  3
# --- 38023.07471513748 seconds ---
# Coeficiente silueta --- 38024.50741624832 seconds ---
# 0.08773246412264711
# Bootstrap, k =  4
# --- 38117.50023698807 seconds ---
# Coeficiente silueta --- 38118.96310520172 seconds ---
# 0.12948407499419307
# bootstrap #  54
# Matriz de distancias (triangulo superior) --- 38457.38675451279 seconds ---
# Espejo --- 38564.428141355515 seconds ---
# Bootstrap, k =  2
# --- 38626.82238650322 seconds ---
# Coeficiente silueta --- 38628.66069769859 seconds ---
# 0.7793189913527664
# Bootstrap, k =  3
# --- 38712.305166721344 seconds ---
# Coeficiente silueta --- 38713.79209494591 seconds ---
# 0.08354029074918423
# Bootstrap, k =  4
# --- 38809.362087249756 seconds ---
# Coeficiente silueta --- 38811.17449951172 seconds ---
# 0.7497601218847388
# bootstrap #  55
# Matriz de distancias (triangulo superior) --- 39155.618545770645 seconds ---
# Espejo --- 39265.97430443764 seconds ---
# Bootstrap, k =  2
# --- 39329.64981007576 seconds ---
# Coeficiente silueta --- 39331.47334384918 seconds ---
# 0.7522982455278746
# Bootstrap, k =  3
# --- 39425.63317108154 seconds ---
# Coeficiente silueta --- 39427.06967353821 seconds ---
# 0.08371072609104546
# Bootstrap, k =  4
# --- 39539.2280151844 seconds ---
# Coeficiente silueta --- 39541.00990462303 seconds ---
# 0.7694974815738668
# bootstrap #  56
# Matriz de distancias (triangulo superior) --- 39880.46390533447 seconds ---
# Espejo --- 39988.09944462776 seconds ---
# Bootstrap, k =  2
# --- 40050.98612499237 seconds ---
# Coeficiente silueta --- 40052.81451535225 seconds ---
# 0.7750629875879183
# Bootstrap, k =  3
# --- 40168.15903258324 seconds ---
# Coeficiente silueta --- 40169.62391138077 seconds ---
# 0.08432494195437731
# Bootstrap, k =  4
# --- 40256.63158130646 seconds ---
# Coeficiente silueta --- 40258.43872618675 seconds ---
# 0.7341773829071582
# bootstrap #  57
# Matriz de distancias (triangulo superior) --- 40602.62404179573 seconds ---
# Espejo --- 40711.136800289154 seconds ---
# Bootstrap, k =  2
# --- 40771.433015584946 seconds ---
# Coeficiente silueta --- 40773.27039647102 seconds ---
# 0.9037172926667509
# Bootstrap, k =  3
# --- 40865.02676439285 seconds ---
# Coeficiente silueta --- 40866.84408950806 seconds ---
# 0.8023507758969357
# Bootstrap, k =  4
# --- 40950.170547008514 seconds ---
# Coeficiente silueta --- 40951.636694431305 seconds ---
# 0.131147645947197
# bootstrap #  58
# Matriz de distancias (triangulo superior) --- 41296.329053878784 seconds ---
# Espejo --- 41404.53836417198 seconds ---
# Bootstrap, k =  2
# --- 41467.470613241196 seconds ---
# Coeficiente silueta --- 41469.2961435318 seconds ---
# 0.7444281071434793
# Bootstrap, k =  3
# --- 41563.49006271362 seconds ---
# Coeficiente silueta --- 41565.28988146782 seconds ---
# 0.7785526292880589
# Bootstrap, k =  4
# --- 41645.87205910683 seconds ---
# Coeficiente silueta --- 41647.69107103348 seconds ---
# 0.7633213451849209
# bootstrap #  59
# Matriz de distancias (triangulo superior) --- 41986.49022293091 seconds ---
# Espejo --- 42094.42528963089 seconds ---
# Bootstrap, k =  2
# --- 42153.73065948486 seconds ---
# Coeficiente silueta --- 42155.54512095451 seconds ---
# 0.7601311173601069
# Bootstrap, k =  3
# --- 42258.41221523285 seconds ---
# Coeficiente silueta --- 42259.85940480232 seconds ---
# 0.09207158881013763
# Bootstrap, k =  4
# --- 42359.90898036957 seconds ---
# Coeficiente silueta --- 42361.720438718796 seconds ---
# 0.7111666192252439
# bootstrap #  60
# Matriz de distancias (triangulo superior) --- 42701.59707951546 seconds ---
# Espejo --- 42810.34094595909 seconds ---
# Bootstrap, k =  2
# --- 42872.62487864494 seconds ---
# Coeficiente silueta --- 42874.45185518265 seconds ---
# 0.8983749805908111
# Bootstrap, k =  3
# --- 42964.78486704826 seconds ---
# Coeficiente silueta --- 42966.599838256836 seconds ---
# 0.7898093834782269
# Bootstrap, k =  4
# --- 43064.73685669899 seconds ---
# Coeficiente silueta --- 43066.55495071411 seconds ---
# 0.780956227814464
# bootstrap #  61
# Matriz de distancias (triangulo superior) --- 43405.750233888626 seconds ---
# Espejo --- 43514.18587589264 seconds ---
# Bootstrap, k =  2
# --- 43577.02362513542 seconds ---
# Coeficiente silueta --- 43578.862283706665 seconds ---
# 0.736337906576599
# Bootstrap, k =  3
# --- 43688.63321828842 seconds ---
# Coeficiente silueta --- 43690.44127869606 seconds ---
# 0.7810419755916395
# Bootstrap, k =  4
# --- 43783.62239933014 seconds ---
# Coeficiente silueta --- 43785.11162900925 seconds ---
# 0.14255166352610782
# bootstrap #  62
# Matriz de distancias (triangulo superior) --- 44128.504722595215 seconds ---
# Espejo --- 44237.33362317085 seconds ---
# Bootstrap, k =  2
# --- 44302.20923495293 seconds ---
# Coeficiente silueta --- 44304.02589941025 seconds ---
# 0.8993934834218399
# Bootstrap, k =  3
# --- 44403.86729168892 seconds ---
# Coeficiente silueta --- 44405.34712719917 seconds ---
# 0.06294472506267235
# Bootstrap, k =  4
# --- 44505.21541929245 seconds ---
# Coeficiente silueta --- 44507.02168774605 seconds ---
# 0.7484209751645977
# bootstrap #  63
# Matriz de distancias (triangulo superior) --- 44853.499750614166 seconds ---
# Espejo --- 44963.98311686516 seconds ---
# Bootstrap, k =  2
# --- 45030.51842045784 seconds ---
# Coeficiente silueta --- 45032.34888935089 seconds ---
# 0.7340674344702371
# Bootstrap, k =  3
# --- 45123.75532078743 seconds ---
# Coeficiente silueta --- 45125.19881606102 seconds ---
# 0.08668744045927931
# Bootstrap, k =  4
# --- 45225.86760377884 seconds ---
# Coeficiente silueta --- 45227.66156125069 seconds ---
# 0.7693578551195759
# bootstrap #  64
# Matriz de distancias (triangulo superior) --- 45574.096668958664 seconds ---
# Espejo --- 45683.23682975769 seconds ---
# Bootstrap, k =  2
# --- 45737.649515390396 seconds ---
# Coeficiente silueta --- 45739.508890628815 seconds ---
# 0.8916690439050345
# Bootstrap, k =  3
# --- 45831.40836048126 seconds ---
# Coeficiente silueta --- 45832.877870082855 seconds ---
# 0.07471055642857839
# Bootstrap, k =  4
# --- 45951.27121305466 seconds ---
# Coeficiente silueta --- 45952.759706020355 seconds ---
# 0.13062933091750464
# bootstrap #  65
# Matriz de distancias (triangulo superior) --- 46301.62727499008 seconds ---
# Espejo --- 46412.740705251694 seconds ---
# Bootstrap, k =  2
# --- 46481.54872393608 seconds ---
# Coeficiente silueta --- 46483.39180517197 seconds ---
# 0.7595981732275444
# Bootstrap, k =  3
# --- 46588.744784116745 seconds ---
# Coeficiente silueta --- 46590.21688079834 seconds ---
# 0.10493276657456567
# Bootstrap, k =  4
# --- 46685.44843006134 seconds ---
# Coeficiente silueta --- 46686.89696955681 seconds ---
# 0.13051064975332943
# bootstrap #  66
# Matriz de distancias (triangulo superior) --- 47032.29996800423 seconds ---
# Espejo --- 47141.8591799736 seconds ---
# Bootstrap, k =  2
# --- 47203.007677555084 seconds ---
# Coeficiente silueta --- 47204.86873483658 seconds ---
# 0.7505862423410795
# Bootstrap, k =  3
# --- 47291.96952176094 seconds ---
# Coeficiente silueta --- 47293.43585419655 seconds ---
# 0.09892971177221428
# Bootstrap, k =  4
# --- 47386.770332574844 seconds ---
# Coeficiente silueta --- 47388.2366836071 seconds ---
# 0.1268548253204453
# bootstrap #  67
# Matriz de distancias (triangulo superior) --- 47734.235463142395 seconds ---
# Espejo --- 47845.484310626984 seconds ---
# Bootstrap, k =  2
# --- 47913.95091152191 seconds ---
# Coeficiente silueta --- 47915.794889211655 seconds ---
# 0.8944057099762812
# Bootstrap, k =  3
# --- 48028.80534338951 seconds ---
# Coeficiente silueta --- 48030.30343461037 seconds ---
# 0.11718306553828535
# Bootstrap, k =  4
# --- 48162.915583610535 seconds ---
# Coeficiente silueta --- 48164.371651887894 seconds ---
# 0.1094249212768432
# bootstrap #  68
# Matriz de distancias (triangulo superior) --- 48513.72305107117 seconds ---
# Espejo --- 48625.07284998894 seconds ---
# Bootstrap, k =  2
# --- 48694.626002550125 seconds ---
# Coeficiente silueta --- 48696.50069332123 seconds ---
# 0.735471497303436
# Bootstrap, k =  3
# --- 48793.738909482956 seconds ---
# Coeficiente silueta --- 48795.23396253586 seconds ---
# 0.08948669431359474
# Bootstrap, k =  4
# --- 48897.260343790054 seconds ---
# Coeficiente silueta --- 48899.094344854355 seconds ---
# 0.7469617255924021
# bootstrap #  69
# Matriz de distancias (triangulo superior) --- 49247.73692560196 seconds ---
# Espejo --- 49358.794300317764 seconds ---
# Bootstrap, k =  2
# --- 49427.967378139496 seconds ---
# Coeficiente silueta --- 49429.789360523224 seconds ---
# 0.7469646718284264
# Bootstrap, k =  3
# --- 49515.34093165398 seconds ---
# Coeficiente silueta --- 49516.80231714249 seconds ---
# 0.07284110779717003
# Bootstrap, k =  4
# --- 49615.64861249924 seconds ---
# Coeficiente silueta --- 49617.43051528931 seconds ---
# 0.7241847531746299
# bootstrap #  70
# Matriz de distancias (triangulo superior) --- 49964.99308300018 seconds ---
# Espejo --- 50074.34642958641 seconds ---
# Bootstrap, k =  2
# --- 50142.033094882965 seconds ---
# Coeficiente silueta --- 50143.9102332592 seconds ---
# 0.9180411748808611
# Bootstrap, k =  3
# --- 50283.609674453735 seconds ---
# Coeficiente silueta --- 50285.11174201965 seconds ---
# 0.1211038288253624
# Bootstrap, k =  4
# --- 50408.59395337105 seconds ---
# Coeficiente silueta --- 50410.05627965927 seconds ---
# 0.11625730310827552
# bootstrap #  71
# Matriz de distancias (triangulo superior) --- 50755.642495155334 seconds ---
# Espejo --- 50866.7445936203 seconds ---
# Bootstrap, k =  2
# --- 50927.802793979645 seconds ---
# Coeficiente silueta --- 50929.675250053406 seconds ---
# 0.7840438403470367
# Bootstrap, k =  3
# --- 51007.15711975098 seconds ---
# Coeficiente silueta --- 51008.99870967865 seconds ---
# 0.7882137740101094
# Bootstrap, k =  4
# --- 51103.21211695671 seconds ---
# Coeficiente silueta --- 51104.67274069786 seconds ---
# 0.1300623922925531
# bootstrap #  72
# Matriz de distancias (triangulo superior) --- 51454.29998087883 seconds ---
# Espejo --- 51565.6857380867 seconds ---
# Bootstrap, k =  2
# --- 51633.59552168846 seconds ---
# Coeficiente silueta --- 51635.45167326927 seconds ---
# 0.7415049392251558
# Bootstrap, k =  3
# --- 51735.80946063995 seconds ---
# Coeficiente silueta --- 51737.28821372986 seconds ---
# 0.07480491002415028
# Bootstrap, k =  4
# --- 51839.243918180466 seconds ---
# Coeficiente silueta --- 51841.079319000244 seconds ---
# 0.7394557171179891
# bootstrap #  73
# Matriz de distancias (triangulo superior) --- 52190.438323020935 seconds ---
# Espejo --- 52302.081495285034 seconds ---
# Bootstrap, k =  2
# --- 52370.59675168991 seconds ---
# Coeficiente silueta --- 52372.45776748657 seconds ---
# 0.7099913242108469
# Bootstrap, k =  3
# --- 52469.0198469162 seconds ---
# Coeficiente silueta --- 52470.85657906532 seconds ---
# 0.7707408286018689
# Bootstrap, k =  4
# --- 52570.84583854675 seconds ---
# Coeficiente silueta --- 52572.679054260254 seconds ---
# 0.7743551542776296
# bootstrap #  74
# Matriz de distancias (triangulo superior) --- 52921.01302623749 seconds ---
# Espejo --- 53031.56799244881 seconds ---
# Bootstrap, k =  2
# --- 53104.61580467224 seconds ---
# Coeficiente silueta --- 53106.47928404808 seconds ---
# 0.7645882876098535
# Bootstrap, k =  3
# --- 53208.56463098526 seconds ---
# Coeficiente silueta --- 53210.041004896164 seconds ---
# 0.09217862525877142
# Bootstrap, k =  4
# --- 53321.44208288193 seconds ---
# Coeficiente silueta --- 53323.2758231163 seconds ---
# 0.7489751669979892
# bootstrap #  75
# Matriz de distancias (triangulo superior) --- 53671.92180156708 seconds ---
# Espejo --- 53783.43026590347 seconds ---
# Bootstrap, k =  2
# --- 53853.12576007843 seconds ---
# Coeficiente silueta --- 53855.00276637077 seconds ---
# 0.9066824848745413
# Bootstrap, k =  3
# --- 53950.78310751915 seconds ---
# Coeficiente silueta --- 53952.633801460266 seconds ---
# 0.7890995439737499
# Bootstrap, k =  4
# --- 54058.38813304901 seconds ---
# Coeficiente silueta --- 54059.87938308716 seconds ---
# 0.12095717053756422
# bootstrap #  76
# Matriz de distancias (triangulo superior) --- 54412.00511717796 seconds ---
# Espejo --- 54522.106885671616 seconds ---
# Bootstrap, k =  2
# --- 54589.10221862793 seconds ---
# Coeficiente silueta --- 54590.97008895874 seconds ---
# 0.7897628967454445
# Bootstrap, k =  3
# --- 54683.07595539093 seconds ---
# Coeficiente silueta --- 54684.548067331314 seconds ---
# 0.10333134657739558
# Bootstrap, k =  4
# --- 54772.74914598465 seconds ---
# Coeficiente silueta --- 54774.228153944016 seconds ---
# 0.12463228979050549
# bootstrap #  77
# Matriz de distancias (triangulo superior) --- 55125.94111657143 seconds ---
# Espejo --- 55237.645401239395 seconds ---
# Bootstrap, k =  2
# --- 55308.66251373291 seconds ---
# Coeficiente silueta --- 55310.51731300354 seconds ---
# 0.7947917211015967
# Bootstrap, k =  3
# --- 55414.63023519516 seconds ---
# Coeficiente silueta --- 55416.09656572342 seconds ---
# 0.09658701223920799
# Bootstrap, k =  4
# --- 55510.47818470001 seconds ---
# Coeficiente silueta --- 55511.95974159241 seconds ---
# 0.12574400412211384
# bootstrap #  78
# Matriz de distancias (triangulo superior) --- 55861.05628037453 seconds ---
# Espejo --- 55969.850818395615 seconds ---
# Bootstrap, k =  2
# --- 56030.53765082359 seconds ---
# Coeficiente silueta --- 56032.40523505211 seconds ---
# 0.684293177851838
# Bootstrap, k =  3
# --- 56115.81288766861 seconds ---
# Coeficiente silueta --- 56117.292904376984 seconds ---
# 0.06710697091236405
# Bootstrap, k =  4
# --- 56216.20641732216 seconds ---
# Coeficiente silueta --- 56217.69825720787 seconds ---
# 0.13966530089608067
# bootstrap #  79
# Matriz de distancias (triangulo superior) --- 56568.37217617035 seconds ---
# Espejo --- 56680.205001831055 seconds ---
# Bootstrap, k =  2
# --- 56752.99074220657 seconds ---
# Coeficiente silueta --- 56754.82519721985 seconds ---
# 0.7417179638399167
# Bootstrap, k =  3
# --- 56854.21789884567 seconds ---
# Coeficiente silueta --- 56855.68581676483 seconds ---
# 0.09378157375056438
# Bootstrap, k =  4
# --- 56933.19990849495 seconds ---
# Coeficiente silueta --- 56935.01483631134 seconds ---
# 0.7206287308246513
# bootstrap #  80
# Matriz de distancias (triangulo superior) --- 57288.32049894333 seconds ---
# Espejo --- 57398.62511062622 seconds ---
# Bootstrap, k =  2
# --- 57463.21217298508 seconds ---
# Coeficiente silueta --- 57465.04258751869 seconds ---
# 0.7501419355374704
# Bootstrap, k =  3
# --- 57571.83872938156 seconds ---
# Coeficiente silueta --- 57573.63858938217 seconds ---
# 0.7880029562824008
# Bootstrap, k =  4
# --- 57665.94740605354 seconds ---
# Coeficiente silueta --- 57667.74702501297 seconds ---
# 0.7569050636329876
# bootstrap #  81
# Matriz de distancias (triangulo superior) --- 58008.9503595829 seconds ---
# Espejo --- 58118.80993485451 seconds ---
# Bootstrap, k =  2
# --- 58183.34301662445 seconds ---
# Coeficiente silueta --- 58185.17919564247 seconds ---
# 0.7384458752831131
# Bootstrap, k =  3
# --- 58282.252801418304 seconds ---
# Coeficiente silueta --- 58283.70746135712 seconds ---
# 0.07683857419162159
# Bootstrap, k =  4
# --- 58380.39192819595 seconds ---
# Coeficiente silueta --- 58382.18828010559 seconds ---
# 0.7664177095346004
# bootstrap #  82
# Matriz de distancias (triangulo superior) --- 58729.518434762955 seconds ---
# Espejo --- 58840.27910041809 seconds ---
# Bootstrap, k =  2
# --- 58901.48296380043 seconds ---
# Coeficiente silueta --- 58903.354875802994 seconds ---
# 0.7143770660181218
# Bootstrap, k =  3
# --- 58992.64327645302 seconds ---
# Coeficiente silueta --- 58994.48772358894 seconds ---
# 0.7773437067127438
# Bootstrap, k =  4
# --- 59108.63143610954 seconds ---
# Coeficiente silueta --- 59110.48270988464 seconds ---
# 0.7621838784459791
# bootstrap #  83
# Matriz de distancias (triangulo superior) --- 59457.82202458382 seconds ---
# Espejo --- 59569.67427229881 seconds ---
# Bootstrap, k =  2
# --- 59638.62195158005 seconds ---
# Coeficiente silueta --- 59640.48472213745 seconds ---
# 0.7062658691682725
# Bootstrap, k =  3
# --- 59731.61571574211 seconds ---
# Coeficiente silueta --- 59733.45959305763 seconds ---
# 0.7758495219915911
# Bootstrap, k =  4
# --- 59830.311619758606 seconds ---
# Coeficiente silueta --- 59832.11143183708 seconds ---
# 0.7647499443624002
# bootstrap #  84
# Matriz de distancias (triangulo superior) --- 60179.769797325134 seconds ---
# Espejo --- 60288.66667532921 seconds ---
# Bootstrap, k =  2
# --- 60352.06774544716 seconds ---
# Coeficiente silueta --- 60353.921035051346 seconds ---
# 0.7762389805795697
# Bootstrap, k =  3
# --- 60462.13366293907 seconds ---
# Coeficiente silueta --- 60463.59499382973 seconds ---
# 0.08812387523990409
# Bootstrap, k =  4
# --- 60554.57669734955 seconds ---
# Coeficiente silueta --- 60556.41193652153 seconds ---
# 0.7480806618002692
# bootstrap #  85
# Matriz de distancias (triangulo superior) --- 60905.85776305199 seconds ---
# Espejo --- 61017.265364170074 seconds ---
# Bootstrap, k =  2
# --- 61085.91995191574 seconds ---
# Coeficiente silueta --- 61087.78337550163 seconds ---
# 0.7818668319510551
# Bootstrap, k =  3
# --- 61186.54406571388 seconds ---
# Coeficiente silueta --- 61188.01328039169 seconds ---
# 0.10893699505089056
# Bootstrap, k =  4
# --- 61286.91810274124 seconds ---
# Coeficiente silueta --- 61288.366784095764 seconds ---
# 0.13198120664155868
# bootstrap #  86
# Matriz de distancias (triangulo superior) --- 61638.07393121719 seconds ---
# Espejo --- 61747.382583618164 seconds ---
# Bootstrap, k =  2
# --- 61813.9634976387 seconds ---
# Coeficiente silueta --- 61815.82567667961 seconds ---
# 0.7448468905372914
# Bootstrap, k =  3
# --- 61893.731967926025 seconds ---
# Coeficiente silueta --- 61895.20353078842 seconds ---
# 0.07767481943417193
# Bootstrap, k =  4
# --- 61992.87886476517 seconds ---
# Coeficiente silueta --- 61994.718535900116 seconds ---
# 0.7565142027566555
# bootstrap #  87
# Matriz de distancias (triangulo superior) --- 62344.5392165184 seconds ---
# Espejo --- 62455.861867666245 seconds ---
# Bootstrap, k =  2
# --- 62523.08270454407 seconds ---
# Coeficiente silueta --- 62524.58340597153 seconds ---
# 0.06590904330561219
# Bootstrap, k =  3
# --- 62615.07483267784 seconds ---
# Coeficiente silueta --- 62616.54212617874 seconds ---
# 0.08123785141827317
# Bootstrap, k =  4
# --- 62721.38080739975 seconds ---
# Coeficiente silueta --- 62722.84782385826 seconds ---
# 0.11390259345778612
# bootstrap #  88
# Matriz de distancias (triangulo superior) --- 63069.5341758728 seconds ---
# Espejo --- 63180.06141924858 seconds ---
# Bootstrap, k =  2
# --- 63253.82559800148 seconds ---
# Coeficiente silueta --- 63255.68276333809 seconds ---
# 0.7508016688807613
# Bootstrap, k =  3
# --- 63349.343393325806 seconds ---
# Coeficiente silueta --- 63351.16236782074 seconds ---
# 0.7696821899542586
# Bootstrap, k =  4
# --- 63439.110582113266 seconds ---
# Coeficiente silueta --- 63440.94932484627 seconds ---
# 0.752004245631832
# bootstrap #  89
# Matriz de distancias (triangulo superior) --- 63789.736664533615 seconds ---
# Espejo --- 63899.152839660645 seconds ---
# Bootstrap, k =  2
# --- 63961.29317235947 seconds ---
# Coeficiente silueta --- 63963.14004588127 seconds ---
# 0.7543448026919842
# Bootstrap, k =  3
# --- 64045.30214357376 seconds ---
# Coeficiente silueta --- 64046.73198723793 seconds ---
# 0.08467614903183095
# Bootstrap, k =  4
# --- 64146.05712556839 seconds ---
# Coeficiente silueta --- 64147.84589481354 seconds ---
# 0.7448337968732714
# bootstrap #  90
# Matriz de distancias (triangulo superior) --- 64499.9794049263 seconds ---
# Espejo --- 64610.350578546524 seconds ---
# Bootstrap, k =  2
# --- 64680.40721297264 seconds ---
# Coeficiente silueta --- 64681.90592741966 seconds ---
# 0.07388392135619022
# Bootstrap, k =  3
# --- 64778.18287348747 seconds ---
# Coeficiente silueta --- 64779.653584718704 seconds ---
# 0.08494796833152261
# Bootstrap, k =  4
# --- 64881.54561543465 seconds ---
# Coeficiente silueta --- 64883.394857406616 seconds ---
# 0.7367393452267491
# bootstrap #  91
# Matriz de distancias (triangulo superior) --- 65232.34109258652 seconds ---
# Espejo --- 65343.82566571236 seconds ---
# Bootstrap, k =  2
# --- 65413.9446413517 seconds ---
# Coeficiente silueta --- 65415.78889799118 seconds ---
# 0.6919695052900062
# Bootstrap, k =  3
# --- 65491.59362912178 seconds ---
# Coeficiente silueta --- 65493.40920352936 seconds ---
# 0.765160624397262
# Bootstrap, k =  4
# --- 65586.70824050903 seconds ---
# Coeficiente silueta --- 65588.52564191818 seconds ---
# 0.7700483458122835
# bootstrap #  92
# Matriz de distancias (triangulo superior) --- 65940.98985648155 seconds ---
# Espejo --- 66050.95266962051 seconds ---
# Bootstrap, k =  2
# --- 66112.4323515892 seconds ---
# Coeficiente silueta --- 66114.29740285873 seconds ---
# 0.7654166928986561
# Bootstrap, k =  3
# --- 66206.51622843742 seconds ---
# Coeficiente silueta --- 66207.99285840988 seconds ---
# 0.07911906615271051
# Bootstrap, k =  4
# --- 66321.00007534027 seconds ---
# Coeficiente silueta --- 66322.84241390228 seconds ---
# 0.7131320220650322
# bootstrap #  93
# Matriz de distancias (triangulo superior) --- 66665.86122488976 seconds ---
# Espejo --- 66775.233076334 seconds ---
# Bootstrap, k =  2
# --- 66833.89874601364 seconds ---
# Coeficiente silueta --- 66835.74789261818 seconds ---
# 0.7723806165803725
# Bootstrap, k =  3
# --- 66935.12454557419 seconds ---
# Coeficiente silueta --- 66936.9453318119 seconds ---
# 0.7799377638412083
# Bootstrap, k =  4
# --- 67024.49682378769 seconds ---
# Coeficiente silueta --- 67025.96750450134 seconds ---
# 0.11897317205206821
# bootstrap #  94
# Matriz de distancias (triangulo superior) --- 67371.43540811539 seconds ---
# Espejo --- 67480.05622148514 seconds ---
# Bootstrap, k =  2
# --- 67547.54575252533 seconds ---
# Coeficiente silueta --- 67549.40323400497 seconds ---
# 0.7359225317594532
# Bootstrap, k =  3
# --- 67661.81788992882 seconds ---
# Coeficiente silueta --- 67663.65393090248 seconds ---
# 0.7924891430376165
# Bootstrap, k =  4
# --- 67769.26022195816 seconds ---
# Coeficiente silueta --- 67771.08967852592 seconds ---
# 0.7742536028626557
# bootstrap #  95
# Matriz de distancias (triangulo superior) --- 68116.97492790222 seconds ---
# Espejo --- 68228.83375740051 seconds ---
# Bootstrap, k =  2
# --- 68292.76004886627 seconds ---
# Coeficiente silueta --- 68294.64267992973 seconds ---
# 0.7839890926750358
# Bootstrap, k =  3
# --- 68384.83744502068 seconds ---
# Coeficiente silueta --- 68386.32571315765 seconds ---
# 0.11472117813557477
# Bootstrap, k =  4
# --- 68492.76941895485 seconds ---
# Coeficiente silueta --- 68494.22447276115 seconds ---
# 0.13628204889647041
# bootstrap #  96
# Matriz de distancias (triangulo superior) --- 68844.02717351913 seconds ---
# Espejo --- 68953.96911406517 seconds ---
# Bootstrap, k =  2
# --- 69020.66997718811 seconds ---
# Coeficiente silueta --- 69022.50937771797 seconds ---
# 0.7222405440467331
# Bootstrap, k =  3
# --- 69114.11441040039 seconds ---
# Coeficiente silueta --- 69115.93459105492 seconds ---
# 0.7824616177431866
# Bootstrap, k =  4
# --- 69203.85355901718 seconds ---
# Coeficiente silueta --- 69205.36691617966 seconds ---
# 0.14372720000673675
# bootstrap #  97
# Matriz de distancias (triangulo superior) --- 69553.98220133781 seconds ---
# Espejo --- 69666.13295412064 seconds ---
# Bootstrap, k =  2
# --- 69731.45191907883 seconds ---
# Coeficiente silueta --- 69733.29687571526 seconds ---
# 0.7525905637371234
# Bootstrap, k =  3
# --- 69844.39052271843 seconds ---
# Coeficiente silueta --- 69845.84749221802 seconds ---
# 0.1002944632787857
# Bootstrap, k =  4
# --- 69932.862865448 seconds ---
# Coeficiente silueta --- 69934.31722426414 seconds ---
# 0.12710606493408833
# bootstrap #  98
# Matriz de distancias (triangulo superior) --- 70281.04789090157 seconds ---
# Espejo --- 70392.95917224884 seconds ---
# Bootstrap, k =  2
# --- 70456.55388021469 seconds ---
# Coeficiente silueta --- 70458.42666530609 seconds ---
# 0.7607073410274201
# Bootstrap, k =  3
# --- 70560.31936144829 seconds ---
# Coeficiente silueta --- 70561.7944920063 seconds ---
# 0.10448658331511747
# Bootstrap, k =  4
# --- 70653.90525102615 seconds ---
# Coeficiente silueta --- 70655.34862971306 seconds ---
# 0.1275220896504855
# bootstrap #  99

# %%
for i in kValues:
  print('Mediana para k = ',i);
  print(median(silueta[i-min(kValues)][1:nBootstrap+1]));

# %%
silueta = pd.DataFrame(silueta)
