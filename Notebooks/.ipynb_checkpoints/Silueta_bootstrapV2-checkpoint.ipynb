# %% [markdown]
# <a href="https://colab.research.google.com/github/rjnakano/manejo-inventarios-pdg/blob/main/Notebooks/Silueta_bootstrapV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install --upgrade kmodes
# Out:
# Requirement already up-to-date: kmodes in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.13.3 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.0.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.19.5)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from kmodes) (0.22.2.post1)

# %%
import pathlib
import pandas as pd
import numpy as np
from pylab import *

from sklearn.preprocessing import StandardScaler

from kmodes.kprototypes import KPrototypes

import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx

import seaborn as sns
# %matplotlib inline
sns.set_context('poster')
sns.set_style('white')
sns.set_color_codes()

from plotnine import *
import plotnine

# %%
plot_kwds = {'alpha' : 0.5, 's' : 1, 'linewidths':0}

# %%
if str(pathlib.Path().absolute()).find('content') >= 0:
    from google.colab import drive
    drive.mount('/content/gdrive')
    sourcepath = '/content/gdrive/MyDrive/TDGdata'
else:
    sourcepath = '../Datos/Transformed'
print(sourcepath)
# Out:
# ../Datos/Transformed

# %%
# Dataset de inventarios sin dimensiones de los productos
data1 = pd.read_csv("{}/dfNoSupervisado_fixed.csv".format(sourcepath))

# %%
data1['AISLE']=data1['AISLE'].astype(str)
data1.drop('Unnamed: 0', inplace=True, axis=1)

# %%
data1.dtypes
# Out:
# AISLE        object
# IG           object
# HTS          object
# PLANNING     object
# ABC          object
# UOM          object
# CAT          object
# COSTX       float64
# QTYVAR      float64
# dtype: object

# %%
data1.head(5)
# Out:
#   AISLE    IG     HTS PLANNING ABC UOM    CAT     COSTX    QTYVAR
# 0    17  IG56  HTS119      1/1   B  PC  CAT17 -0.029976 -0.037185
# 1    17  IG56  HTS119      1/1   B  PC  CAT17  0.092472 -0.006928
# 2    17  IG56  HTS119      1/1   C  PC  CAT17  0.266130  0.020450
# 3    17  IG56  HTS119      1/1   B  PC  CAT17 -0.025112 -0.044259
# 4    15  IG56  HTS119      1/1   C  PC  CAT17 -0.077982 -0.046471

# %%
# scikit-learn bootstrap
from sklearn.utils import resample

# %%
# Matriz de distancias
dm = pd.read_csv("{}/scores_fixed.csv".format(sourcepath),header=None)
dm=dm.to_numpy()

# %%
type(dm)
# Out:
# numpy.ndarray

# %%
import numba as nb

def get_scores(idx, dm, N):
    scores = set_scores(N)
    return generate_distance(idx, dm, N, scores)

def set_scores(N):
    return np.array([[0.0]*N]*N, dtype=np.float64)

@nb.njit
def generate_distance(idx, dm, N, scores):
    for i in range(N):
        for j in range(i+1,N):
            scores[i][j]=dm[idx[i]][idx[j]]
    # Espejo
    for i in range(0,N):
        for j in range(0,i):
              scores[i][j]=scores[j][i]
    return scores

# %%
# Precompilar
boot = resample(data1, replace=True, n_samples=5, random_state=1)
# %time scores = get_scores(boot.index.to_numpy(),dm,5)
scores
# Out:
# Wall time: 335 ms
# array([[0.        , 2.50001447, 3.1198955 , 3.55266256, 3.18729462],
#        [2.50001447, 0.        , 2.12192583, 3.05702773, 2.68987114],
#        [3.1198955 , 2.12192583, 0.        , 2.65774094, 2.00754673],
#        [3.55266256, 3.05702773, 2.65774094, 0.        , 2.59655895],
#        [3.18729462, 2.68987114, 2.00754673, 2.59655895, 0.        ]])

# %%
# Coeficiente silueta para K 2-3
kValues = [2, 3]
gamma = 0.5
nBootstrap = 100
# Inicializamos la matriz de coeficientes silueta con ceros
silueta = [ [ 0 for j in range(nBootstrap + 1) ] for i in range(len(kValues)) ]
catColumnsPos = [data1.columns.get_loc(col) for col in list(data1.select_dtypes('object').columns)]
N = data1.shape[0]

# %%
from sklearn.metrics import silhouette_score
import time
start_time = time.time()
for k in kValues:
  print('Dataset original, k = ', k)
  kprototype = KPrototypes(n_jobs = -1, n_clusters = k, init = 'Huang', gamma = gamma, random_state = 0)
  kprototype.fit_predict(data1, categorical = catColumnsPos)
  print("--- %s seconds ---" % (time.time() - start_time))
  silueta[k-min(kValues)][0] = silhouette_score(dm, kprototype.labels_, metric='precomputed')
  print("Coeficiente silueta --- %s seconds ---" % (time.time() - start_time))
  print(silueta[k-min(kValues)][0])

for b in range(1,nBootstrap+1):
  print('bootstrap # ',b);
  boot = resample(data1, replace=True, n_samples=N, random_state=b)
  # %time scores = get_scores(boot.index.to_numpy(),dm,N)
  for k in kValues:
    print('Bootstrap, k = ', k)
    kprototypebs = KPrototypes(n_jobs = -1, n_clusters = k, init = 'Huang', gamma = gamma, random_state = 1)
    kprototypebs.fit_predict(boot, categorical = catColumnsPos)
    print("--- %s seconds ---" % (time.time() - start_time));
    silueta[k-min(kValues)][b] = silhouette_score(scores, kprototypebs.labels_, metric='precomputed')
    print("Coeficiente silueta --- %s seconds ---" % (time.time() - start_time))
    print(silueta[k-min(kValues)][b])
# Out:
# Dataset original, k =  2
# --- 23.36100673675537 seconds ---
# Coeficiente silueta --- 27.1089084148407 seconds ---
# 0.7368900959494543
# Dataset original, k =  3
# --- 51.971904039382935 seconds ---
# Coeficiente silueta --- 55.70210289955139 seconds ---
# 0.7187617117905637
# bootstrap #  1
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 80.63299107551575 seconds ---
# Coeficiente silueta --- 82.06686162948608 seconds ---
# 0.785403719753729
# Bootstrap, k =  3
# --- 109.46121096611023 seconds ---
# Coeficiente silueta --- 110.88413977622986 seconds ---
# 0.8004287100371626
# bootstrap #  2
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 138.17328190803528 seconds ---
# Coeficiente silueta --- 139.5953242778778 seconds ---
# 0.7482729047623066
# Bootstrap, k =  3
# --- 162.19521760940552 seconds ---
# Coeficiente silueta --- 163.40697646141052 seconds ---
# 0.060572932085086593
# bootstrap #  3
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 189.0046558380127 seconds ---
# Coeficiente silueta --- 190.43293976783752 seconds ---
# 0.7833639734870986
# Bootstrap, k =  3
# --- 218.03020858764648 seconds ---
# Coeficiente silueta --- 219.22954893112183 seconds ---
# 0.1035677392899332
# bootstrap #  4
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 249.10110807418823 seconds ---
# Coeficiente silueta --- 250.5181634426117 seconds ---
# 0.7671755260132802
# Bootstrap, k =  3
# --- 274.47787070274353 seconds ---
# Coeficiente silueta --- 275.6691896915436 seconds ---
# 0.09736044296679294
# bootstrap #  5
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 301.88677620887756 seconds ---
# Coeficiente silueta --- 303.31326055526733 seconds ---
# 0.8844608729533359
# Bootstrap, k =  3
# --- 324.9955563545227 seconds ---
# Coeficiente silueta --- 326.4027693271637 seconds ---
# 0.7642524474780523
# bootstrap #  6
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 353.7800512313843 seconds ---
# Coeficiente silueta --- 355.2170248031616 seconds ---
# 0.7329938138443358
# Bootstrap, k =  3
# --- 375.5633432865143 seconds ---
# Coeficiente silueta --- 376.99979615211487 seconds ---
# 0.779801841681975
# bootstrap #  7
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 401.31549310684204 seconds ---
# Coeficiente silueta --- 402.7429413795471 seconds ---
# 0.7347631693310004
# Bootstrap, k =  3
# --- 426.37045645713806 seconds ---
# Coeficiente silueta --- 427.57348108291626 seconds ---
# 0.10642492783852717
# bootstrap #  8
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 453.36466240882874 seconds ---
# Coeficiente silueta --- 454.7970745563507 seconds ---
# 0.7613105515424048
# Bootstrap, k =  3
# --- 475.81375670433044 seconds ---
# Coeficiente silueta --- 477.0045244693756 seconds ---
# 0.0924294546309581
# bootstrap #  9
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 500.45379400253296 seconds ---
# Coeficiente silueta --- 501.8884518146515 seconds ---
# 0.7349521302037406
# Bootstrap, k =  3
# --- 522.2659974098206 seconds ---
# Coeficiente silueta --- 523.5232074260712 seconds ---
# 0.0698171837244874
# bootstrap #  10
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 548.8900036811829 seconds ---
# Coeficiente silueta --- 550.3281066417694 seconds ---
# 0.901055287522377
# Bootstrap, k =  3
# --- 574.579029083252 seconds ---
# Coeficiente silueta --- 576.0059144496918 seconds ---
# 0.7813253857989764
# bootstrap #  11
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 601.6369521617889 seconds ---
# Coeficiente silueta --- 603.0734989643097 seconds ---
# 0.7481298879256494
# Bootstrap, k =  3
# --- 625.7366034984589 seconds ---
# Coeficiente silueta --- 626.9517307281494 seconds ---
# 0.10360681540257191
# bootstrap #  12
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 651.4690058231354 seconds ---
# Coeficiente silueta --- 652.9114890098572 seconds ---
# 0.7431807253694824
# Bootstrap, k =  3
# --- 674.7093198299408 seconds ---
# Coeficiente silueta --- 676.1436705589294 seconds ---
# 0.7892661248009117
# bootstrap #  13
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 700.712729215622 seconds ---
# Coeficiente silueta --- 702.1486737728119 seconds ---
# 0.7282158074872545
# Bootstrap, k =  3
# --- 724.1234910488129 seconds ---
# Coeficiente silueta --- 725.3196365833282 seconds ---
# 0.08049750685417102
# bootstrap #  14
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 752.6325871944427 seconds ---
# Coeficiente silueta --- 754.066061258316 seconds ---
# 0.7037022781104166
# Bootstrap, k =  3
# --- 779.6230094432831 seconds ---
# Coeficiente silueta --- 781.0533947944641 seconds ---
# 0.7818575614348899
# bootstrap #  15
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 806.0343518257141 seconds ---
# Coeficiente silueta --- 807.4619376659393 seconds ---
# 0.780507250593981
# Bootstrap, k =  3
# --- 831.4249567985535 seconds ---
# Coeficiente silueta --- 832.6746482849121 seconds ---
# 0.0850548424392792
# bootstrap #  16
# Wall time: 11 s
# Bootstrap, k =  2
# --- 859.5766108036041 seconds ---
# Coeficiente silueta --- 860.9980270862579 seconds ---
# 0.7815466933351168
# Bootstrap, k =  3
# --- 886.1705136299133 seconds ---
# Coeficiente silueta --- 887.3683393001556 seconds ---
# 0.1050496544765781
# bootstrap #  17
# Wall time: 11 s
# Bootstrap, k =  2
# --- 914.6841320991516 seconds ---
# Coeficiente silueta --- 916.1108839511871 seconds ---
# 0.8970291655583456
# Bootstrap, k =  3
# --- 941.2274830341339 seconds ---
# Coeficiente silueta --- 942.425986289978 seconds ---
# 0.07755098446961531
# bootstrap #  18
# Wall time: 10.8 s
# Bootstrap, k =  2
# ---
# --- 2071.2934081554413 seconds ---
# Coeficiente silueta --- 2072.736938238144 seconds ---
# 0.7566375839600229
# Bootstrap, k =  3
# --- 2098.6953179836273 seconds ---
# Coeficiente silueta --- 2099.945450782776 seconds ---
# 0.11281990993880359
# bootstrap #  40
# Wall time: 11.1 s
# Bootstrap, k =  2
# --- 2125.3321537971497 seconds ---
# Coeficiente silueta --- 2126.7834169864655 seconds ---
# 0.7654551558739219
# Bootstrap, k =  3
# --- 2149.721899986267 seconds ---
# Coeficiente silueta --- 2150.9263010025024 seconds ---
# 0.09701902578311042
# bootstrap #  41
# Wall time: 11 s
# Bootstrap, k =  2
# --- 2175.9914968013763 seconds ---
# Coeficiente silueta --- 2177.4362592697144 seconds ---
# 0.893200192825341
# Bootstrap, k =  3
# --- 2200.327439546585 seconds ---
# Coeficiente silueta --- 2201.7943551540375 seconds ---
# 0.7835096159664153
# bootstrap #  42
# Wall time: 11 s
# Bootstrap, k =  2
# --- 2227.3350315093994 seconds ---
# Coeficiente silueta --- 2228.7857418060303 seconds ---
# 0.7371117808508889
# Bootstrap, k =  3
# --- 2255.3025376796722 seconds ---
# Coeficiente silueta --- 2256.559109687805 seconds ---
# 0.08447813763430212
# bootstrap #  43
# Wall time: 11 s
# Bootstrap, k =  2
# --- 2282.8425402641296 seconds ---
# Coeficiente silueta --- 2284.2884180545807 seconds ---
# 0.7572090538281996
# Bootstrap, k =  3
# --- 2304.7886548042297 seconds ---
# Coeficiente silueta --- 2305.999879837036 seconds ---
# 0.07862804162953169
# bootstrap #  44
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 2330.534002304077 seconds ---
# Coeficiente silueta --- 2331.9692447185516 seconds ---
# 0.7154840626297786
# Bootstrap, k =  3
# --- 2352.5796818733215 seconds ---
# Coeficiente silueta --- 2354.0076739788055 seconds ---
# 0.7741716605249536
# bootstrap #  45
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 2380.3009221553802 seconds ---
# Coeficiente silueta --- 2381.8549275398254 seconds ---
# 0.7634238045125826
# Bootstrap, k =  3
# --- 2408.154680967331 seconds ---
# Coeficiente silueta --- 2409.3757679462433 seconds ---
# 0.09928759134257381
# bootstrap #  46
# Wall time: 11 s
# Bootstrap, k =  2
# --- 2434.4640822410583 seconds ---
# Coeficiente silueta --- 2435.9237105846405 seconds ---
# 0.6960332373390195
# Bootstrap, k =  3
# --- 2460.5960376262665 seconds ---
# Coeficiente silueta --- 2462.048069000244 seconds ---
# 0.7681779178661717
# bootstrap #  47
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 2486.70859003067 seconds ---
# Coeficiente silueta --- 2488.1458106040955 seconds ---
# 0.7749165611329244
# Bootstrap, k =  3
# --- 2514.355621814728 seconds ---
# Coeficiente silueta --- 2515.561486721039 seconds ---
# 0.1056976353726512
# bootstrap #  48
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 2540.7682540416718 seconds ---
# Coeficiente silueta --- 2542.2276198863983 seconds ---
# 0.8936863939120334
# Bootstrap, k =  3
# --- 2563.3419058322906 seconds ---
# Coeficiente silueta --- 2564.5697753429413 seconds ---
# 0.07601172873252157
# bootstrap #  49
# Wall time: 11 s
# Bootstrap, k =  2
# --- 2591.632431268692 seconds ---
# Coeficiente silueta --- 2593.1112208366394 seconds ---
# 0.7215644663172364
# Bootstrap, k =  3
# --- 2616.4790692329407 seconds ---
# Coeficiente silueta --- 2617.6955919265747 seconds ---
# 0.08900637561241355
# bootstrap #  50
# Wall time: 11 s
# Bootstrap, k =  2
# --- 2643.588321208954 seconds ---
# Coeficiente silueta --- 2645.071220397949 seconds ---
# 0.7499047083184613
# Bootstrap, k =  3
# --- 2667.8660662174225 seconds ---
# Coeficiente silueta --- 2669.0608723163605 seconds ---
# 0.09288666131407802
# bootstrap #  51
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 2693.95037817955 seconds ---
# Coeficiente silueta --- 2695.373571872711 seconds ---
# 0.7482130366751583
# Bootstrap, k =  3
# --- 2721.0419220924377 seconds ---
# Coeficiente silueta --- 2722.2227368354797 seconds ---
# 0.09014506602115818
# bootstrap #  52
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 2749.3472154140472 seconds ---
# Coeficiente silueta --- 2750.7524609565735 seconds ---
# 0.7568268185099393
# Bootstrap, k =  3
# --- 2771.4929642677307 seconds ---
# Coeficiente silueta --- 2772.6818113327026 seconds ---
# 0.08145941643542443
# bootstrap #  53
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 2797.668652534485 seconds ---
# Coeficiente silueta --- 2799.1219058036804 seconds ---
# 0.9001980908109065
# Bootstrap, k =  3
# --- 2824.070543527603 seconds ---
# Coeficiente silueta --- 2825.258364200592 seconds ---
# 0.08788220122643974
# bootstrap #  54
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 2849.4406883716583 seconds ---
# Coeficiente silueta --- 2850.8628854751587 seconds ---
# 0.7793598996559652
# Bootstrap, k =  3
# --- 2871.628347635269 seconds ---
# Coeficiente silueta --- 2872.817151069641 seconds ---
# 0.08383392714339644
# bootstrap #  55
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 2897.405415534973 seconds ---
# Coeficiente silueta --- 2898.8186268806458 seconds ---
# 0.7523404694636766
# Bootstrap, k =  3
# --- 2923.9743478298187 seconds ---
# Coeficiente silueta --- 2925.158185005188 seconds ---
# 0.08464999040005601
# bootstrap #  56
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 2949.384419441223 seconds ---
# Coeficiente silueta --- 2950.805618286133 seconds ---
# 0.7751269750368733
# Bootstrap, k =  3
# --- 2973.5248551368713 seconds ---
# Coeficiente silueta --- 2974.7316279411316 seconds ---
# 0.08424423737354987
# bootstrap #  57
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 2998.149340867996 seconds ---
# Coeficiente silueta --- 2999.5675201416016 seconds ---
# 0.9037731516452852
# Bootstrap, k =  3
# --- 3020.110601425171 seconds ---
# Coeficiente silueta --- 3021.514848470688 seconds ---
# 0.8021135205168841
# bootstrap #  58
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 3046.0930857658386 seconds ---
# Coeficiente silueta --- 3047.509298324585 seconds ---
# 0.7444635463954401
# Bootstrap, k =  3
# --- 3066.4893910884857 seconds ---
# Coeficiente silueta --- 3067.885657310486 seconds ---
# 0.7787292241954087
# bootstrap #  59
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 3092.4602665901184 seconds ---
# Coeficiente silueta --- 3093.872489929199 seconds ---
# 0.7601876188256552
# Bootstrap, k =  3
# --- 3117.869558572769 seconds ---
# Coeficiente silueta --- 3119.0493714809418 seconds ---
# 0.09264165926846522
# bootstrap #  60
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 3143.7162551879883 seconds ---
# Coeficiente silueta --- 3145.129682302475 seconds ---
# 0.8993868616118833
# Bootstrap, k =  3
# --- 3164.6801993846893 seconds ---
# Coeficiente silueta --- 3166.084443807602 seconds ---
# 0.7899640810801261
# bootstrap #  61
# Wall time: 10.8 s
# Bootstrap, k =  2
# ---
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 3772.371885061264 seconds ---
# Coeficiente silueta --- 3773.787100315094 seconds ---
# 0.7415439951771199
# Bootstrap, k =  3
# --- 3794.9801530838013 seconds ---
# Coeficiente silueta --- 3796.162180662155 seconds ---
# 0.0763162866238197
# bootstrap #  73
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 3820.2455966472626 seconds ---
# Coeficiente silueta --- 3821.6558253765106 seconds ---
# 0.8781543670672532
# Bootstrap, k =  3
# --- 3842.9953393936157 seconds ---
# Coeficiente silueta --- 3844.395251750946 seconds ---
# 0.771001936106196
# bootstrap #  74
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 3875.328948020935 seconds ---
# Coeficiente silueta --- 3876.7448201179504 seconds ---
# 0.7646265988135588
# Bootstrap, k =  3
# --- 3900.0453231334686 seconds ---
# Coeficiente silueta --- 3901.228159427643 seconds ---
# 0.09302380726565272
# bootstrap #  75
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 3926.1221690177917 seconds ---
# Coeficiente silueta --- 3927.53794836998 seconds ---
# 0.9067276801520572
# Bootstrap, k =  3
# --- 3953.808413028717 seconds ---
# Coeficiente silueta --- 3955.210695505142 seconds ---
# 0.7892228359134912
# bootstrap #  76
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 3982.939157485962 seconds ---
# Coeficiente silueta --- 3984.3653700351715 seconds ---
# 0.7898258106318763
# Bootstrap, k =  3
# --- 4005.4736149311066 seconds ---
# Coeficiente silueta --- 4006.649480819702 seconds ---
# 0.10331976662980877
# bootstrap #  77
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 4032.0425629615784 seconds ---
# Coeficiente silueta --- 4033.456780910492 seconds ---
# 0.7948621856368041
# Bootstrap, k =  3
# --- 4056.6840002536774 seconds ---
# Coeficiente silueta --- 4057.862846851349 seconds ---
# 0.09763034574172152
# bootstrap #  78
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 4082.697615146637 seconds ---
# Coeficiente silueta --- 4084.116856813431 seconds ---
# 0.8851268810436873
# Bootstrap, k =  3
# --- 4101.445230960846 seconds ---
# Coeficiente silueta --- 4102.623054027557 seconds ---
# 0.06705431011710362
# bootstrap #  79
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 4127.5424473285675 seconds ---
# Coeficiente silueta --- 4128.970660209656 seconds ---
# 0.7417519861802505
# Bootstrap, k =  3
# --- 4156.231379270554 seconds ---
# Coeficiente silueta --- 4157.420198202133 seconds ---
# 0.09467969758992098
# bootstrap #  80
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 4182.508553981781 seconds ---
# Coeficiente silueta --- 4183.926887512207 seconds ---
# 0.7501813231699548
# Bootstrap, k =  3
# --- 4210.046268224716 seconds ---
# Coeficiente silueta --- 4211.446583509445 seconds ---
# 0.7854847430340566
# bootstrap #  81
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 4235.406973838806 seconds ---
# Coeficiente silueta --- 4236.815302371979 seconds ---
# 0.7384706210820992
# Bootstrap, k =  3
# --- 4257.466832637787 seconds ---
# Coeficiente silueta --- 4258.646738767624 seconds ---
# 0.08821979182774924
# bootstrap #  82
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 4281.864582061768 seconds ---
# Coeficiente silueta --- 4283.272354364395 seconds ---
# 0.7143787267856692
# Bootstrap, k =  3
# --- 4301.2095539569855 seconds ---
# Coeficiente silueta --- 4302.601407527924 seconds ---
# 0.7730761382458025
# bootstrap #  83
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 4326.838606834412 seconds ---
# Coeficiente silueta --- 4328.245877027512 seconds ---
# 0.7062642831292558
# Bootstrap, k =  3
# --- 4351.593534946442 seconds ---
# Coeficiente silueta --- 4353.006847143173 seconds ---
# 0.7744164807336226
# bootstrap #  84
# Wall time: 10.6 s
# Bootstrap, k =  2
# --- 4377.548312187195 seconds ---
# Coeficiente silueta --- 4378.961768388748 seconds ---
# 0.7762810017637631
# Bootstrap, k =  3
# --- 4411.132253885269 seconds ---
# Coeficiente silueta --- 4412.307111501694 seconds ---
# 0.08937325008292558
# bootstrap #  85
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 4436.627720832825 seconds ---
# Coeficiente silueta --- 4438.050884962082 seconds ---
# 0.7819365864570035
# Bootstrap, k =  3
# --- 4456.569142341614 seconds ---
# Coeficiente silueta --- 4457.747190475464 seconds ---
# 0.10879125098531961
# bootstrap #  86
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 4485.965382575989 seconds ---
# Coeficiente silueta --- 4487.375639200211 seconds ---
# 0.7448883868957602
# Bootstrap, k =  3
# --- 4508.10101723671 seconds ---
# Coeficiente silueta --- 4509.288814544678 seconds ---
# 0.07787533146052315
# bootstrap #  87
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 4534.5599620342255 seconds ---
# Coeficiente silueta --- 4535.756243467331 seconds ---
# 0.06529864517191224
# Bootstrap, k =  3
# --- 5602.61646437645 seconds ---
# Coeficiente silueta --- 5604.061274290085 seconds ---
# 0.07196463809966415
# bootstrap #  88
# Wall time: 16.8 s
# Bootstrap, k =  2
# C:\Users\KameLaptop\.conda\envs\pdg\lib\site-packages\joblib\externals\loky\process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
# --- 5639.808018922806 seconds ---
# Coeficiente silueta --- 5641.225229978561 seconds ---
# 0.7508434857975423
# Bootstrap, k =  3
# --- 5660.868723869324 seconds ---
# Coeficiente silueta --- 5662.288898944855 seconds ---
# 0.7699123974458983
# bootstrap #  89
# Wall time: 10.9 s
# Bootstrap, k =  2
# --- 5691.605539798737 seconds ---
# Coeficiente silueta --- 5693.027708292007 seconds ---
# 0.7547151519859796
# Bootstrap, k =  3
# --- 5714.368524551392 seconds ---
# Coeficiente silueta --- 5715.543384313583 seconds ---
# 0.08574052858872579
# bootstrap #  90
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 5741.6545560359955 seconds ---
# Coeficiente silueta --- 5742.841382026672 seconds ---
# 0.07268186403910713
# Bootstrap, k =  3
# --- 5765.902525424957 seconds ---
# Coeficiente silueta --- 5767.104283094406 seconds ---
# 0.08408826995279198
# bootstrap #  91
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 5796.41894030571 seconds ---
# Coeficiente silueta --- 5797.833154439926 seconds ---
# 0.69197080412929
# Bootstrap, k =  3
# --- 5817.62619304657 seconds ---
# Coeficiente silueta --- 5819.0264484882355 seconds ---
# 0.7655847189867514
# bootstrap #  92
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 5844.417596817017 seconds ---
# Coeficiente silueta --- 5845.836799860001 seconds ---
# 0.7654481724447793
# Bootstrap, k =  3
# --- 5866.299104690552 seconds ---
# Coeficiente silueta --- 5867.472992658615 seconds ---
# 0.08099231871865921
# bootstrap #  93
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 5896.192111253738 seconds ---
# Coeficiente silueta --- 5897.651202201843 seconds ---
# 0.773088417005485
# Bootstrap, k =  3
# --- 5928.093794345856 seconds ---
# Coeficiente silueta --- 5929.5050168037415 seconds ---
# 0.7802719019587561
# bootstrap #  94
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 5957.62938952446 seconds ---
# Coeficiente silueta --- 5959.05554318428 seconds ---
# 0.7359266987986932
# Bootstrap, k =  3
# --- 5994.168673753738 seconds ---
# Coeficiente silueta --- 5995.37744140625 seconds ---
# 0.0745837369973975
# bootstrap #  95
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 6022.003257036209 seconds ---
# Coeficiente silueta --- 6023.414455413818 seconds ---
# 0.7843313620757482
# Bootstrap, k =  3
# --- 6048.016656637192 seconds ---
# Coeficiente silueta --- 6049.207499742508 seconds ---
# 0.11461014316822911
# bootstrap #  96
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 6074.127913475037 seconds ---
# Coeficiente silueta --- 6075.543128967285 seconds ---
# 0.7222387820254986
# Bootstrap, k =  3
# --- 6099.2132658958435 seconds ---
# Coeficiente silueta --- 6100.616512060165 seconds ---
# 0.7829506547735475
# bootstrap #  97
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 6125.769242048264 seconds ---
# Coeficiente silueta --- 6127.186452150345 seconds ---
# 0.7529350284168098
# Bootstrap, k =  3
# --- 6157.599117040634 seconds ---
# Coeficiente silueta --- 6158.7809545993805 seconds ---
# 0.10042092222296241
# bootstrap #  98
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 6181.445736885071 seconds ---
# Coeficiente silueta --- 6182.859980106354 seconds ---
# 0.7607934378891671
# Bootstrap, k =  3
# --- 6206.731139421463 seconds ---
# Coeficiente silueta --- 6207.928909540176 seconds ---
# 0.10543525951153562
# bootstrap #  99
# Wall time: 10.8 s
# Bootstrap, k =  2
# --- 6230.4900777339935 seconds ---
# Coeficiente silueta --- 6231.681890487671 seconds ---
# 0.06418573661945007
# Bootstrap, k =  3
# --- 6250.741916418076 seconds ---
# Coeficiente silueta --- 6251.924724340439 seconds ---
# 0.08032976779820195
# bootstrap #  100
# Wall time: 10.7 s
# Bootstrap, k =  2
# --- 6275.248361587524 seconds ---
# Coeficiente silueta --- 6276.653636217117 seconds ---
# 0.8924078753012372
# Bootstrap, k =  3
# --- 6296.958324670792 seconds ---
# Coeficiente silueta --- 6298.142189741135 seconds ---
# 0.087035138918055

# %%
for i in kValues:
  print('Mediana para k = ',i);
  print(median(silueta[i-min(kValues)][1:nBootstrap+1]));
# Out:
# Mediana para k =  2
# 0.7552700048506455
# Mediana para k =  3
# 0.09700181894374368

# %%
silueta_df = pd.DataFrame(silueta)
#np.savetxt("/content/gdrive/MyDrive/TDGdata/siluetaboot.csv", silueta, delimiter=",")

# %%
silueta_df = silueta_df.T
silueta_df.columns=['k2','k3']

# %%
silueta_df[1:].describe()
# Out:
#                k2          k3
# count  100.000000  100.000000
# mean     0.746529    0.276295
# std      0.168257    0.307544
# min      0.064186    0.060573
# 25%      0.735904    0.084205
# 50%      0.755270    0.097002
# 75%      0.783549    0.764586
# max      0.998792    0.802114

# %%
silueta_df.to_csv('{}/silueta_fixed_data.csv'.format(sourcepath))

# %%
print('Mediana k2 = {}'.format(median(silueta_df.k2[1:])))
# Out:
# Mediana k2 = 0.7552700048506455

# %%
median(silueta_df.k3[1:])
# Out:
# 0.09700181894374368

# %%
for i in silueta_df.columns:
    print('Mediana {} = {}'.format(i,median(silueta_df[i][1:])))
# Out:
# Mediana k2 = 0.7552700048506455
# Mediana k3 = 0.09700181894374368
