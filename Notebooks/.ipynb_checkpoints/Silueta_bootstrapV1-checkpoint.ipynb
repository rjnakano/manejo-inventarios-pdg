# %% [markdown]
# <a href="https://colab.research.google.com/github/rjnakano/manejo-inventarios-pdg/blob/main/Notebooks/Silueta_bootstrapV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install --upgrade kmodes
# !pip install plotnine
# !pip install google.colab

# %%
import pathlib
import pandas as pd
import numpy as np
from pylab import *

from sklearn.preprocessing import StandardScaler

from kmodes.kprototypes import KPrototypes

import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx

import seaborn as sns
# %matplotlib inline
sns.set_context('poster')
sns.set_style('white')
sns.set_color_codes()

from plotnine import *
import plotnine

# %%
plot_kwds = {'alpha' : 0.5, 's' : 1, 'linewidths':0}

# %%
if str(pathlib.Path().absolute()).find('content') >= 0:
    from google.colab import drive
    drive.mount('/content/gdrive')
    sourcepath = '/content/gdrive/MyDrive/TDGdata'
else:
    sourcepath = '../Datos/Transformed'
print(sourcepath)
# Out:
# ../Datos/Transformed

# %%
# Dataset de inventarios sin dimensiones de los productos
data1 = pd.read_csv("{}/df042421.csv".format(sourcepath))

# %%
data1['AISLE']=data1['AISLE'].astype(str)

# %%
# Out:
# count    1.624400e+04
# mean    -2.652209e-16
# std      1.000031e+00
# min     -1.438117e-01
# 25%     -8.904898e-02
# 50%     -3.557862e-02
# 75%     -2.920971e-02
# max      8.095984e+01
# Name: QTYVAR, dtype: float64

# %%
data1.dtypes
# Out:
# AISLE        object
# IG           object
# HTS          object
# PLANNING     object
# ABC          object
# UOM          object
# CAT          object
# COSTX       float64
# QTYVAR      float64
# dtype: object

# %%
data1.head(5)
# Out:
#   AISLE    IG     HTS PLANNING ABC UOM    CAT     COSTX    QTYVAR
# 0    17  IG56  HTS119      1/1   B  PC  CAT17 -0.029671 -0.037167
# 1    17  IG56  HTS119      1/1   B  PC  CAT17  0.092655 -0.006905
# 2    17  IG56  HTS119      1/1   C  PC  CAT17  0.266138  0.020477
# 3    17  IG56  HTS119      1/1   B  PC  CAT17 -0.024812 -0.044242
# 4    15  IG56  HTS119      1/1   C  PC  CAT17 -0.077628 -0.046455

# %%
# scikit-learn bootstrap
from sklearn.utils import resample

# %%
# Matriz de distancias
dm = pd.read_csv("{}/distances.csv".format(sourcepath))
dm=dm.to_numpy()

# %%
import numba as nb
@nb.njit
def dist_num_njit(data):
    scores = np.zeros((len(data),len(data)), dtype=np.float64)
    valor = nb.float64(0)

    for i in range(len(data)):
        for j in range(i+1, len(data)):
            valor = nb.float64(np.sum((data[i] - data[j]) ** 2))
            scores[i][j] = valor
    return scores

def dist_cat(data, catWeight):
    scores = np.zeros((len(data),len(data)), dtype=np.float64)
    for i in range(len(data)):
        for j in range(i+1, len(data)):
            scores[i][j] = np.float64(np.sum(data[i]!=data[j])*catWeight)
    return scores

@nb.njit
def traspose_njit (data):
    scores = data
    for i in range(len(data)):
        for j in range(1+i,len(data)):
            scores[j][i] = scores[i][j]
    return scores 

first_run = True # Se utiliza para precompilar los algoritmos mejorados con numba

# %%
# Coeficiente silueta para K 2-4
kValues = [3, 4]
gamma = 0.5
nBootstrap = 20
# Inicializamos la matriz de coeficientes silueta con ceros
silueta = [ [ 0 for j in range(nBootstrap + 1) ] for i in range(len(kValues)) ]
catColumnsPos = [data1.columns.get_loc(col) for col in list(data1.select_dtypes('object').columns)]
numColumnsPos = [data1.columns.get_loc(col) for col in list(data1.select_dtypes('float64').columns)]
N = data1.shape[0]

# %%
from sklearn.metrics import silhouette_score
import time
start_time = time.time()
for k in kValues:
  print('k = ', k)
  kprototype = KPrototypes(n_jobs = -1, n_clusters = k, init = 'Huang', gamma = gamma, random_state = 0)
  kprototype.fit_predict(data1, categorical = catColumnsPos)
  print("--- %s seconds ---" % (time.time() - start_time))
  silueta[k-min(kValues)][0] = silhouette_score(dm, kprototype.labels_, metric='precomputed')
  print("Coeficiente silueta --- %s seconds ---" % (time.time() - start_time))
  print(silueta[k-min(kValues)][0])
  for b in range(1,nBootstrap+1):
    print('bootstrap # ',b);
    boot = resample(data1, replace=True, n_samples=data1.shape[0], random_state=b)
    # Fit the cluster
    kprototypebs = KPrototypes(n_jobs = -1, n_clusters = k, init = 'Huang', gamma = gamma, random_state = 1)
    kprototypebs.fit_predict(boot, categorical = catColumnsPos)
    print("--- %s seconds ---" % (time.time() - start_time));
    
    # boot dividido en atributos numericas y categoricos
    dataNum=boot.iloc[:,numColumnsPos]
    dataNum=dataNum.to_numpy()
    dataCat=boot.iloc[:,catColumnsPos]
    dataCat=dataCat.to_numpy()
    
    # Precompila el algoritmo de numba
    if first_run == True:
        print('Precompilar calculador de distancias')
        # %time dist_num_np = dist_num_njit(dataNum[range(10)])
        # %time dist_cat_np = dist_cat(dataCat[range(10)], gamma)
        # %time scores = np.sum([dist_cat_np, dist_num_np], axis=0)
        # %time scores = traspose_njit(scores)
        first_run = False
    
    print('Cálculo de distancias bootstrap {} con {} clusters'.format(b,k))
    # %time dist_num_np = dist_num_njit(dataNum[range(N)])
    # %time dist_cat_np = dist_cat(dataCat[range(N)], gamma)
    # %time scores = np.sum([dist_cat_np, dist_num_np], axis=0)
    # %time scores = traspose_njit(scores)
    
    
#     # Inicializamos la matriz de distancias con ceros
#     scores = [ [ 0 for i in range(N) ] for j in range(N) ]
#     # Calculamos la mitad de la matriz distancias
#     for i in range(N):
#       for j in range(i+1,N):
#         scores[i][j]=np.sum((dataNum[i] - dataNum[j]) ** 2) + gamma * np.sum(dataCat[i]!=dataCat[j])
#     print("Matriz de distancias --- %s seconds ---" % (time.time() - start_time))
#     # Completamos la matriz
#     for i in range(0,N):
#       for j in range(0,i):
#         scores[i][j]=scores[j][i]
    print("Espejo --- %s seconds ---" % (time.time() - start_time))
    silueta[k-min(kValues)][b] = silhouette_score(scores, kprototypebs.labels_, metric='precomputed')
    print("Coeficiente silueta --- %s seconds ---" % (time.time() - start_time))
    print(silueta[k-min(kValues)][b])
# Out:
# k =  3
# --- 21.467751264572144 seconds ---
# Coeficiente silueta --- 25.111001014709473 seconds ---
# 0.7182138218409522
# bootstrap #  1
# --- 49.28831100463867 seconds ---
# Precompilar calculador de distancias
# Wall time: 357 ms
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 93.4 ms
# Cálculo de distancias bootstrap 1 con 3 clusters
# Wall time: 15.7 s
# Wall time: 16min 48s
# Wall time: 2.12 s
# Wall time: 994 ms
# Espejo --- 1077.578875541687 seconds ---
# Coeficiente silueta --- 1078.7569379806519 seconds ---
# 0.09330388061499972
# bootstrap #  2
# --- 1103.2861075401306 seconds ---
# Cálculo de distancias bootstrap 2 con 3 clusters
# Wall time: 15.6 s
# Wall time: 16min 41s
# Wall time: 2.29 s
# Wall time: 987 ms
# Espejo --- 2124.099014043808 seconds ---
# Coeficiente silueta --- 2125.2709085941315 seconds ---
# 0.0795551613919883
# bootstrap #  3
# --- 2155.676869869232 seconds ---
# Cálculo de distancias bootstrap 3 con 3 clusters
# Wall time: 16.1 s
# Wall time: 16min 59s
# Wall time: 2.19 s
# Wall time: 995 ms
# Espejo --- 3194.590072631836 seconds ---
# Coeficiente silueta --- 3195.772915124893 seconds ---
# 0.08579445355521252
# bootstrap #  4
# --- 3222.36763381958 seconds ---
# Cálculo de distancias bootstrap 4 con 3 clusters
# Wall time: 16 s
# Wall time: 16min 36s
# Wall time: 2.13 s
# Wall time: 1e+03 ms
# Espejo --- 4238.253784418106 seconds ---
# Coeficiente silueta --- 4239.653102636337 seconds ---
# 0.7848836886437416
# bootstrap #  5
# --- 4265.376470565796 seconds ---
# Cálculo de distancias bootstrap 5 con 3 clusters
# Wall time: 15.8 s
# Wall time: 16min 37s
# Wall time: 2.15 s
# Wall time: 987 ms
# Espejo --- 5282.133964538574 seconds ---
# Coeficiente silueta --- 5283.547156095505 seconds ---
# 0.7580501112931499
# bootstrap #  6
# --- 5312.400147199631 seconds ---
# Cálculo de distancias bootstrap 6 con 3 clusters
# Wall time: 15.8 s
# Wall time: 16min 30s
# Wall time: 2.24 s
# Wall time: 999 ms
# Espejo --- 6321.92153096199 seconds ---
# Coeficiente silueta --- 6323.133415222168 seconds ---
# 0.09604875554522227
# bootstrap #  7
# --- 6351.614273548126 seconds ---
# Cálculo de distancias bootstrap 7 con 3 clusters
# Wall time: 15.6 s
# Wall time: 16min 24s
# Wall time: 2.15 s
# Wall time: 990 ms
# Espejo --- 7355.353261232376 seconds ---
# Coeficiente silueta --- 7356.532415151596 seconds ---
# 0.08272228147006884
# bootstrap #  8
# --- 7377.007872343063 seconds ---
# Cálculo de distancias bootstrap 8 con 3 clusters
# Wall time: 15.6 s
# Wall time: 16min 48s
# Wall time: 2.28 s
# Wall time: 1.01 s
# Espejo --- 8404.843502759933 seconds ---
# Coeficiente silueta --- 8406.074209928513 seconds ---
# 0.08775924380328577
# bootstrap #  9
# --- 8427.527802467346 seconds ---
# Cálculo de distancias bootstrap 9 con 3 clusters
# Wall time: 15.5 s
# Wall time: 16min 26s
# Wall time: 2.28 s
# Wall time: 984 ms
# Espejo --- 9432.695885896683 seconds ---
# Coeficiente silueta --- 9433.869571685791 seconds ---
# 0.1008091939490596
# bootstrap #  10
# --- 9457.032601833344 seconds ---
# Cálculo de distancias bootstrap 10 con 3 clusters
# Wall time: 15.5 s
# Wall time: 16min 7s
# Wall time: 2.19 s
# Wall time: 1 s
# Espejo --- 10443.56774187088 seconds ---
# Coeficiente silueta --- 10444.743657112122 seconds ---
# 0.10999866521757545
# bootstrap #  11
# --- 10473.676746368408 seconds ---
# Cálculo de distancias bootstrap 11 con 3 clusters
# Wall time: 15.5 s
# Wall time: 16min 28s
# Wall time: 2.55 s
# Wall time: 997 ms
# Espejo --- 11481.406199455261 seconds ---
# Coeficiente silueta --- 11482.632917642593 seconds ---
# 0.12736999263905782
# bootstrap #  12
# --- 11506.844165563583 seconds ---
# Cálculo de distancias bootstrap 12 con 3 clusters
# Wall time: 15.7 s
# Wall time: 16min 38s
# Wall time: 2.37 s
# Wall time: 1 s
# Espejo --- 12524.089539766312 seconds ---
# Coeficiente silueta --- 12525.30329322815 seconds ---
# 0.08529892407285644
# bootstrap #  13
# --- 12552.68209195137 seconds ---
# Cálculo de distancias bootstrap 13 con 3 clusters
# Wall time: 15.5 s
# Wall time: 16min 47s
# Wall time: 2.35 s
# Wall time: 1.02 s
# Espejo --- 13579.04275226593 seconds ---
# Coeficiente silueta --- 13580.274457454681 seconds ---
# 0.10477446840618314
# bootstrap #  14
# --- 13617.722336053848 seconds ---
# Cálculo de distancias bootstrap 14 con 3 clusters
# Wall time: 15.8 s
# Wall time: 17min 2s
# Wall time: 2.36 s
# Wall time: 988 ms
# Espejo --- 14658.926127672195 seconds ---
# Coeficiente silueta --- 14660.385227441788 seconds ---
# 0.7925131592452925
# bootstrap #  15
# --- 14693.201486110687 seconds ---
# Cálculo de distancias bootstrap 15 con 3 clusters
# Wall time: 15.8 s
# Wall time: 17min 12s
# Wall time: 2.49 s
# Wall time: 1.07 s
# Espejo --- 15745.470619440079 seconds ---
# Coeficiente silueta --- 15746.739279270172 seconds ---
# 0.08379381515543731
# bootstrap #  16
# --- 15774.298397302628 seconds ---
# Cálculo de distancias bootstrap 16 con 3 clusters
# Wall time: 15.9 s
# Wall time: 18min 32s
# Wall time: 2.76 s
# Wall time: 1.26 s
# Espejo --- 16906.822494745255 seconds ---
# Coeficiente silueta --- 16908.477591991425 seconds ---
# 0.7799059521528896
# bootstrap #  17
# --- 16956.09482526779 seconds ---
# Cálculo de distancias bootstrap 17 con 3 clusters
# Wall time: 17.6 s
# Wall time: 17min 31s
# Wall time: 2.55 s
# Wall time: 1.07 s
# Espejo --- 18029.159418344498 seconds ---
# Coeficiente silueta --- 18030.453724861145 seconds ---
# 0.1250009241378602
# bootstrap #  18
# --- 18062.741985082626 seconds ---
# Cálculo de distancias bootstrap 18 con 3 clusters
# Wall time: 18.2 s
# Wall time: 17min 42s
# Wall time: 2.56 s
# Wall time: 1.03 s
# Espejo --- 19146.897119283676 seconds ---
# Coeficiente silueta --- 19148.162519693375 seconds ---
# 0.07779559025875957
# bootstrap #  19
# --- 19175.808482646942 seconds ---
# Cálculo de distancias bootstrap 19 con 3 clusters
# Wall time: 15.9 s
# Wall time: 17min 7s
# Wall time: 2.29 s
# Wall time: 1 s
# Espejo --- 20222.94077014923 seconds ---
# Coeficiente silueta --- 20224.141918182373 seconds ---
# 0.08067551807392272
# bootstrap #  20
# --- 20252.124706983566 seconds ---
# Cálculo de distancias bootstrap 20 con 3 clusters
# Wall time: 15.8 s
# Wall time: 16min 42s
# Wall time: 2.32 s
# Wall time: 1.03 s
# Espejo --- 21273.364645004272 seconds ---
# Coeficiente silueta --- 21274.63178062439 seconds ---
# 0.08299601690496457
# k =  4
# --- 21297.82005739212 seconds ---
# Coeficiente silueta --- 21303.454893112183 seconds ---
# 0.7507712291842021
# bootstrap #  1
# --- 21327.911462545395 seconds ---
# Cálculo de distancias bootstrap 1 con 4 clusters
# Wall time: 15.7 s
# Wall time: 16min 32s
# Wall time: 2.44 s
# Wall time: 1.06 s
# Espejo --- 22339.430900335312 seconds ---
# Coeficiente silueta --- 22340.686553239822 seconds ---
# 0.123667752437498
# bootstrap #  2
# --- 22364.286491155624 seconds ---
# Cálculo de distancias bootstrap 2 con 4 clusters
# Wall time: 15.5 s
# Wall time: 17min 9s
# Wall time: 2.46 s
# Wall time: 990 ms
# Espejo --- 23412.493103027344 seconds ---
# Coeficiente silueta --- 23413.90201663971 seconds ---
# 0.7566801991889119
# bootstrap #  3
# --- 23447.66935968399 seconds ---
# Cálculo de distancias bootstrap 3 con 4 clusters
# Wall time: 15.5 s
# Wall time: 16min 17s
# Wall time: 2.23 s
# Wall time: 1.01 s
# Espejo --- 24444.263362407684 seconds ---
# Coeficiente silueta --- 24445.653299093246 seconds ---
# 0.7449492595601183
# bootstrap #  4
# --- 24474.466237068176 seconds ---
# Cálculo de distancias bootstrap 4 con 4 clusters
# Wall time: 15.5 s
# Wall time: 16min 18s
# Wall time: 2.16 s
# Wall time: 1 s
# Espejo --- 25471.184926748276 seconds ---
# Coeficiente silueta --- 25472.58554291725 seconds ---
# 0.773342891525885
# bootstrap #  5
# --- 25494.15504002571 seconds ---
# Cálculo de distancias bootstrap 5 con 4 clusters
# Wall time: 15.4 s
# Wall time: 16min 16s
# Wall time: 2.16 s
# Wall time: 1 s
# Espejo --- 26489.186675310135 seconds ---
# Coeficiente silueta --- 26490.582285881042 seconds ---
# 0.7369201592353902
# bootstrap #  6
# --- 26513.42255616188 seconds ---
# Cálculo de distancias bootstrap 6 con 4 clusters
# Wall time: 15.4 s
# Wall time: 16min 26s
# Wall time: 2.15 s
# Wall time: 1.01 s
# Espejo --- 27518.287754058838 seconds ---
# Coeficiente silueta --- 27519.683672189713 seconds ---
# 0.7501565513476068
# bootstrap #  7
# --- 27555.70943260193 seconds ---
# Cálculo de distancias bootstrap 7 con 4 clusters
# Wall time: 15.5 s
# Wall time: 16min 19s
# Wall time: 2.2 s
# Wall time: 985 ms
# Espejo --- 28554.201307296753 seconds ---
# Coeficiente silueta --- 28555.598047733307 seconds ---
# 0.7134535728495904
# bootstrap #  8
# --- 28582.425512313843 seconds ---
# Cálculo de distancias bootstrap 8 con 4 clusters
# Wall time: 15.5 s
# Wall time: 16min 18s
# Wall time: 2.23 s
# Wall time: 992 ms
# Espejo --- 29579.840169906616 seconds ---
# Coeficiente silueta --- 29581.23490524292 seconds ---
# 0.7723386443651569
# bootstrap #  9
# --- 29619.806607484818 seconds ---
# Cálculo de distancias bootstrap 9 con 4 clusters
# Wall time: 15.4 s
# Wall time: 16min 19s
# Wall time: 2.16 s
# Wall time: 989 ms
# Espejo --- 30618.020050764084 seconds ---
# Coeficiente silueta --- 30619.426718235016 seconds ---
# 0.7503756482354623
# bootstrap #  10
# --- 30643.19041800499 seconds ---
# Cálculo de distancias bootstrap 10 con 4 clusters
# Wall time: 15.5 s
# Wall time: 16min 29s
# Wall time: 2.25 s
# Wall time: 1e+03 ms
# Espejo --- 31651.408756017685 seconds ---
# Coeficiente silueta --- 31652.811079740524 seconds ---
# 0.7426714582364835
# bootstrap #  11
# --- 31678.458962202072 seconds ---
# Cálculo de distancias bootstrap 11 con 4 clusters
# Wall time: 15.4 s
# Wall time: 16min 25s
# Wall time: 2.21 s
# Wall time: 982 ms
# Espejo --- 32682.260909080505 seconds ---
# Coeficiente silueta --- 32683.650280237198 seconds ---
# 0.7760128588092476
# bootstrap #  12
# --- 32710.272693634033 seconds ---
# Cálculo de distancias bootstrap 12 con 4 clusters
# Wall time: 15.9 s
# Wall time: 16min 45s
# Wall time: 2.16 s
# Wall time: 1 s
# Espejo --- 33735.21865105629 seconds ---
# Coeficiente silueta --- 33736.41062831879 seconds ---
# 0.11629638724585832
# bootstrap #  13
# --- 33764.55497097969 seconds ---
# Cálculo de distancias bootstrap 13 con 4 clusters
# Wall time: 15.7 s
# Wall time: 16min 34s
# Wall time: 2.17 s
# Wall time: 995 ms
# Espejo --- 34778.278611421585 seconds ---
# Coeficiente silueta --- 34779.446419239044 seconds ---
# 0.12512664791436034
# bootstrap #  14
# --- 34802.352991104126 seconds ---
# Cálculo de distancias bootstrap 14 con 4 clusters
# Wall time: 15.7 s
# Wall time: 17min 13s
# Wall time: 2.15 s
# Wall time: 1 s
# Espejo --- 35855.048630952835 seconds ---
# Coeficiente silueta --- 35856.46833276749 seconds ---
# 0.7802855781172742
# bootstrap #  15
# --- 35878.253464221954 seconds ---
# Cálculo de distancias bootstrap 15 con 4 clusters
# Wall time: 16.3 s
# Wall time: 17min 26s
# Wall time: 2.17 s
# Wall time: 1.01 s
# Espejo --- 36944.545411109924 seconds ---
# Coeficiente silueta --- 36945.74425458908 seconds ---
# 0.1404263553693604
# bootstrap #  16
# --- 36967.19550704956 seconds ---
# Cálculo de distancias bootstrap 16 con 4 clusters
# Wall time: 16.1 s
# Wall time: 17min 11s
# Wall time: 2.16 s
# Wall time: 1 s
# Espejo --- 38018.48238706589 seconds ---
# Coeficiente silueta --- 38019.87696647644 seconds ---
# 0.7481649464247122
# bootstrap #  17
# --- 38048.72410225868 seconds ---
# Cálculo de distancias bootstrap 17 con 4 clusters
# Wall time: 15.5 s
# Wall time: 16min 30s
# Wall time: 2.31 s
# Wall time: 1 s
# Espejo --- 39057.85799527168 seconds ---
# Coeficiente silueta --- 39059.03948998451 seconds ---
# 0.11307373834995871
# bootstrap #  18
# --- 39095.070905685425 seconds ---
# Cálculo de distancias bootstrap 18 con 4 clusters
# Wall time: 15.5 s
# Wall time: 16min 23s
# Wall time: 2.21 s
# Wall time: 990 ms
# Espejo --- 40097.44901561737 seconds ---
# Coeficiente silueta --- 40098.844747543335 seconds ---
# 0.744130313013626
# bootstrap #  19
# --- 40127.42471051216 seconds ---
# Cálculo de distancias bootstrap 19 con 4 clusters
# Wall time: 15.7 s
# Wall time: 16min 28s
# Wall time: 2.21 s
# Wall time: 1 s
# Espejo --- 41135.10395741463 seconds ---
# Coeficiente silueta --- 41136.529542684555 seconds ---
# 0.7652018924137288
# bootstrap #  20
# --- 41168.697340488434 seconds ---
# Cálculo de distancias bootstrap 20 con 4 clusters
# Wall time: 15.6 s
# Wall time: 16min 27s
# Wall time: 2.22 s
# Wall time: 990 ms
# Espejo --- 42175.051223516464 seconds ---
# Coeficiente silueta --- 42176.241572618484 seconds ---
# 0.13717480315670955

# %%
# data1['Cluster'] = kprototype.labels_

# %%
silueta
# Out:
# [[0.7182138218409522,
#   0.09330388061499972,
#   0.0795551613919883,
#   0.08579445355521252,
#   0.7848836886437416,
#   0.7580501112931499,
#   0.09604875554522227,
#   0.08272228147006884,
#   0.08775924380328577,
#   0.1008091939490596,
#   0.10999866521757545,
#   0.12736999263905782,
#   0.08529892407285644,
#   0.10477446840618314,
#   0.7925131592452925,
#   0.08379381515543731,
#   0.7799059521528896,
#   0.1250009241378602,
#   0.07779559025875957,
#   0.08067551807392272,
#   0.08299601690496457],
#  [0.7507712291842021,
#   0.123667752437498,
#   0.7566801991889119,
#   0.7449492595601183,
#   0.773342891525885,
#   0.7369201592353902,
#   0.7501565513476068,
#   0.7134535728495904,
#   0.7723386443651569,
#   0.7503756482354623,
#   0.7426714582364835,
#   0.7760128588092476,
#   0.11629638724585832,
#   0.12512664791436034,
#   0.7802855781172742,
#   0.1404263553693604,
#   0.7481649464247122,
#   0.11307373834995871,
#   0.744130313013626,
#   0.7652018924137288,
#   0.13717480315670955]]

# %%
np.savetxt('{}/silueta.csv'.format(sourcepath),silueta,delimiter=',')

# %%
for i in kValues:
  print('Mediana para k = ',i);
  print(median(silueta[i-min(kValues)][1:nBootstrap+1]));
# Out:
# Mediana para k =  3
# 0.094676318080111
# Mediana para k =  4
# 0.7445397862868721

# %%
silueta = pd.DataFrame(silueta)

# %%
silueta_transposed = silueta.T[1:]
silueta_transposed.columns = kValues
silueta_transposed.describe()
# Out:
#                3          4
# count  20.000000  20.000000
# mean    0.230952   0.565522
# std     0.281465   0.295675
# min     0.077796   0.113074
# 25%     0.083594   0.139613
# 50%     0.094676   0.744540
# 75%     0.125593   0.758811
# max     0.792513   0.780286
